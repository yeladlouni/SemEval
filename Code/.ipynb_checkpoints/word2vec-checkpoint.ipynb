# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
from tempfile import gettempdir
import zipfile
import pickle

from bidi.algorithm import get_display
import arabic_reshaper

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

from nltk.corpus import stopwords
from nltk.stem import ISRIStemmer
from nltk import wordpunct_tokenize

import PyArabic

# %%
def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    local_filename = os.path.join('.', filename)

    statinfo = os.stat(local_filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified', filename)
    else:
        print(statinfo.st_size)
        raise Exception('Failed to verify ' + local_filename +
                        '. Can you get to it with a browser?')
    return local_filename


filename = maybe_download('webteb.zip',  81750261)
# Out:
# Found and verified webteb.zip

# %%
import io
# Read the data into a list of strings.
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words."""
    
    with zipfile.ZipFile(filename) as f:
        data = wordpunct_tokenize(tf.compat.as_str(f.read(f.namelist()[0])))
        return data


vocabulary = read_data(filename)
print('Data size', len(set(vocabulary)))
# Out:
# Data size 313999

# %%
print(vocabulary[20001])
# Out:
# اتباعها

# %%
def preprocess_word(word):
    preprocess = PyArabic.ArabicPreprocessor()
    word = preprocess.deNoise(word)
    return word

def process_data(data):
    
    stopwords_list = stopwords.words('arabic')
    stemmer = ISRIStemmer()
    
    data = [stemmer.stem(word) for word in data if word not in stopwords_list]
    
    return data

# %%
#vocabulary = process_data(vocabulary)

# %%
# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 100000


def build_dataset(words, n_words):
    """Process raw inputs into a dataset."""
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(n_words - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        index = dictionary.get(word, 0)
        if index == 0:  # dictionary['UNK']
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reversed_dictionary


# Filling 4 global variables:
# data - list of codes (integers from 0 to vocabulary_size-1).
#   This is the original text but words are replaced by their codes
# count - map of words(strings) to count of occurrences
# dictionary - map of words(strings) to their codes(integers)
# reverse_dictionary - maps codes(integers) to words(strings)
data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,
                                                            vocabulary_size)
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0
# Out:
# Most common words (+UNK) [['UNK', 488624], ('،', 1418836), ('.', 865446), ('من', 768570), ('في', 732988)]
# Sample data [452, 6438, 766, 107, 166, 286, 1678, 867, 6325, 0] ['#', "'", 'فقدان', 'ُ', 'الوزن', 'ِ', 'شعور', 'ٌ', 'رائع', 'UNK']

# %%
# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    if data_index + span > len(data):
        data_index = 0
    buffer.extend(data[data_index:data_index + span])
    data_index += span
    for i in range(batch_size // num_skips):
        context_words = [w for w in range(span) if w != skip_window]
        words_to_use = random.sample(context_words, num_skips)
        for j, context_word in enumerate(words_to_use):
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[context_word]
        if data_index == len(data):
            for word in data[:span]:
                buffer.append(word)
            data_index = span
        else:
            buffer.append(data[data_index])
            data_index += 1
    # Backtrack a little bit to avoid skipping words in the end of a batch
    data_index = (data_index + len(data) - span) % len(data)
    return batch, labels


batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
    print(batch[i], reverse_dictionary[batch[i]],
          '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 6438 ' -> 452 #
# 6438 ' -> 766 فقدان
# 766 فقدان -> 6438 '
# 766 فقدان -> 107 ُ
# 107 ُ -> 166 الوزن
# 107 ُ -> 766 فقدان
# 166 الوزن -> 107 ُ
# 166 الوزن -> 286 ِ

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1  # How many words to consider left and right.
num_skips = 2  # How many times to reuse an input to generate a label.
num_sampled = 64  # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. These 3 variables are used only for
# displaying model accuracy, they don't affect calculation.
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)

graph = tf.Graph()

with graph.as_default():
    # Input data.
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Ops and variables pinned to the CPU because of missing GPU implementation
    with tf.device('/cpu:0'):
        # Look up embeddings for inputs.
        embeddings = tf.Variable(
            tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
        embed = tf.nn.embedding_lookup(embeddings, train_inputs)

        # Construct the variables for the NCE loss
        nce_weights = tf.Variable(
            tf.truncated_normal([vocabulary_size, embedding_size],
                                stddev=1.0 / math.sqrt(embedding_size)))
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Compute the average NCE loss for the batch.
    # tf.nce_loss automatically draws a new sample of the negative labels each
    # time we evaluate the loss.
    # Explanation of the meaning of NCE loss:
    #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
    loss = tf.reduce_mean(
        tf.nn.nce_loss(weights=nce_weights,
                       biases=nce_biases,
                       labels=train_labels,
                       inputs=embed,
                       num_sampled=num_sampled,
                       num_classes=vocabulary_size))

    # Construct the SGD optimizer using a learning rate of 1.0.
    optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

    # Compute the cosine similarity between minibatch examples and all embeddings.
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(
        valid_embeddings, normalized_embeddings, transpose_b=True)

    # Add variable initializer.
    init = tf.global_variables_initializer()

# %%
# Step 5: Begin training.
num_steps = 300000
LOG_DIR = './logs/word2vec'

with tf.Session(graph=graph) as session:
    # We must initialize all variables before we use them.
    init.run()
    print('Initialized')
    saver = tf.train.Saver()
    average_loss = 0
    for step in xrange(num_steps):
        batch_inputs, batch_labels = generate_batch(
            batch_size, num_skips, skip_window)
        feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

        # We perform one update step by evaluating the optimizer op (including it
        # in the list of returned values for session.run()
        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val

        if step % 2000 == 0:
            if step > 0:
                average_loss /= 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step ', step, ': ', average_loss)
            average_loss = 0

        # Note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in xrange(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log_str = 'Nearest to %s:' % valid_word
                for k in xrange(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = '%s %s,' % (log_str, close_word)
                print(log_str)
        
            saver.save(session, os.path.join(LOG_DIR, "model.ckpt"), step)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  306.1876220703125
# Nearest to علاج: small, جذاب, مجالسة, reduction, بكدمات, الهوت, مساعدة, لإنتقال,
# Nearest to منع: تكوينه, وكتب, شريانين, الحملي, مجهوداتك, وطأة, وإصابته, حينا,
# Nearest to و: وج, الفرن, وأخبرها, عيونى, الاستعانه, لدحض, الزغب, وتهيئتها,
# Nearest to السلام: بمفاس, ومفاصل, العربيات, similar, سما, كشفت, ونقلت, وأسبوعان,
# Nearest to تناول: ولذلك, وبتكرار, كإصابته, مشفى, وثخانة, didi, أجوع, بامكانهم,
# Nearest to من: مغطي, 237750, ٍّ, وأخبرت, ناقصا, الصراحه, والأوتار, والتمر,
# Nearest to ،: Cardiolipin, فبـل, أوراقه, ونحافة, سجائر, الإحصاء, فيلوديبين, إبليفاي,
# Nearest to هذه: إضافيين, باانى, حديثـا, بدائت, تصلين, 4شهور, مجدة, فوريكونازول,
# Nearest to الشهرية: نظن, البحار, للعبادة, تلخيصها, والرجفة, المتالع, عند, الاصبعين,
# Nearest to مع: Eye, بالعشرات, الدرقيةFSH, لتصحيحه, البروفسور, والعجري, بالضجر, بروتينية,
# Nearest to بعد: يعطى, ومارايكم, الابتدائية, مضرب, رئيسية, لتاخير, تحتفي, وأنتظر,
# Nearest to على: نستخدم, أساسيتان, صدمة, ليهم, لتجفيفه, DRVV, One, يشبع,
# Nearest to عن: دعائكم, المكونات, الرشح, الريفية, إخوانه, تشجعك, rhinitis, كالحمل,
# Nearest to ؟: اسألى, جناته, بلياليها, neurotop, طفلتان, والكتابة, والوزن, تتذوق,
# Nearest to إلى: لعامة, الإبرة, التعقيب, وحلها, أعطوني, طهى, SAPOFEN, وتنميلا,
# Nearest to لم: نشيطة, والكلمات, للسمنة, Cystoscopy, المصروفة, Urethra, يختل, الالترا,
# Average loss at step  2000 :  151.61696809482575
# Average loss at step  4000 :  84.98471430921555
# Average loss at step  6000 :  59.03342869567871
# Average loss at step  8000 :  45.65467435622215
# Average loss at step  10000 :  35.670991035163404
# Nearest to علاج: حجم, النظر, الجانبين, كولين, بجراحة, مساعدة, Electrolytes, وتشمل,
# Nearest to منع: والغدة, بين, الجرعات, وطأة, البروتين, الخراج, الطويل, 44,
# Nearest to و: وج, عرضي, إكزيما, الزغب, صغار, بالسرطانات, الفرن, للبول,
# Nearest to السلام: بمفاس, العربيات, similar, سما, ونقلت, وأسبوعان, بالشعاع, للصفرة,
# Nearest to تناول: ولذلك, الوصول, تساهم, الملائمة, تهيج, الإثناعشرية, التوقف, حالا,
# Nearest to من: في, التجشؤ, وبينها, الطعم, AstraZeneca, حرارة, وعندما, المبيض,
# Nearest to ،: ., ,, )،, ايجابي, تعتبر, (, احتمالات, ً,
# Nearest to هذه: للتخلص, التصلب, الخثار, رحم, حب, بالنسبة, 796, كلوربروباميد,
# Nearest to الشهرية: تقليل, UNK, الأشعة, الشفة, لقياس, حدوثها, الإستروجينات, القنابل,
# Nearest to مع: الشعر, TNF, كذلك, Eye, بروتينية, خاصه, المرارة, كالسيوم,
# Nearest to بعد: يعطى, رئيسية, الابتدائية, نظم, الأحماض, بديلا, ضاض, مستقبلا,
# Nearest to على: نستخدم, في, تشعر, مضادة, ز, دة, dl, لأجله,
# Nearest to عن: المكونات, بالجهاز, الرشح, صابة, الكوديئين, الحركة, دون, غم,
# Nearest to ؟: والوزن, م, مختلف, حجمه, SPIMACO, وسط, البنسلين, شامل,
# Nearest to إلى: الإبرة, مصحوب, ONCOLOGY, في, وشعورا, تكرار, وراثية, CENTER,
# Nearest to لم: ث, التجاعيد, تأثيرات, ARABIA, وارد, السياقة, Disease, الثعلب,
# Average loss at step  12000 :  28.995228448569776
# Average loss at step  14000 :  24.494256802320482
# Average loss at step  16000 :  20.160079700887202
# Average loss at step  18000 :  17.8627444447279
# Average loss at step  20000 :  14.832943605720997
# Nearest to علاج: reduction, التفاعلية, الجانبين, small, مساعدة, Electrolytes, النظر, reaction,
# Nearest to منع: الحملي, والغدة, يحبذ, الجلوبولين, الجرعات, بين, وطأة, الخراج,
# Nearest to و: وج, UNK, منقول, إكزيما, عرضي, الفرن, صغار, Instillation,
# Nearest to السلام: بمفاس, ومفاصل, similar, كشفت, العربيات, لويحات, ونقلت, وأسبوعان,
# Nearest to تناول: ولذلك, تساهم, التوقف, SAPOFEN, الوصول, ميثيل, 1983, يبقى,
# Nearest to من: النيوميسين, AstraZeneca, الطعم, في, التجشؤ, المتدثرة, الحفاظي, KEPPRA,
# Nearest to ،: ,, ., )،, الجلوبولين, :, AstraZeneca, الكدمة, ),
# Nearest to هذه: رحم, الروماتوئيدي, التصلب, PUREGON, للتخلص, إضافيين, شعورا, VCA,
# Nearest to الشهرية: تقليل, الأشعة, حدوثها, الارتباك, نانوغرام, حالة, المجهول, لقياس,
# Nearest to مع: بروتينية, TNF, كذلك, الجلوبولين, عن, واليابان, Eye, الشعر,
# Nearest to بعد: قبل, مستقبلا, رئيسية, الابتدائية, ovary, ضاض, METHOTREXATE, بديلا,
# Nearest to على: نستخدم, في, تشعر, رصده, ضعي, لأجله, الكروية, التطهير,
# Nearest to عن: لوفاستاتين, المكونات, الرشح, بالجهاز, دون, HBV, صابة, مع,
# Nearest to ؟: والوزن, مختلف, فيناسترايد, البنسلين, لورازيبام, حجمه, فائح, م,
# Nearest to إلى: الى, في, SAPOFEN, الإبرة, ONCOLOGY, مصحوب, بواسطة, والمسؤولة,
# Nearest to لم: نافازولين, الملتويات, ث, SAPOFEN, ELYZOL, التجاعيد, Disease, السياقة,
# Average loss at step  22000 :  13.1475558206141
# Average loss at step  24000 :  11.591973520457744
# Average loss at step  26000 :  10.52631690326333
# Average loss at step  28000 :  9.177810512244701
# Average loss at step  30000 :  10.395461352467537
# Nearest to علاج: reduction, الجانبين, التفاعلية, النظر, البريتون, مساعدة, المخبري, small,
# Nearest to منع: الحملي, زوفران, UNK, والغدة, ثيروتروبين, بين, تينوفوفير, وطأة,
# Nearest to و: وج, منقول, وضغطه, ب, إكزيما, صغار, Instillation, UNK,
# Nearest to السلام: بمفاس, ومفاصل, similar, سما, كشفت, العربيات, ونقلت, لويحات,
# Nearest to تناول: ولذلك, أوكسجين, التوقف, الوصول, البورفرينات, تساهم, SAPOFEN, التوتي,
# Nearest to من: في, النيوميسين, الذ, البريتون, الرجيع, ومن, AstraZeneca, التجشؤ,
# Nearest to ،: ,, ., )،, البريتون, ), ؛, :, ميبهيدرولين,
# Nearest to هذه: التي, لهل, رحم, الروماتوئيدي, ريتاربن, PUREGON, كريسماس, فوريكونازول,
# Nearest to الشهرية: Personality, تينوفوفير, نانوغرام, للديسليتر, خصوي, تقليل, الارتباك, زوفران,
# Nearest to مع: في, البريتون, ثيروتروبين, بروتينية, بواسطة, TNF, امام, Eye,
# Nearest to بعد: قبل, مستقبلا, البريتون, رئيسية, وتضخ, الابتدائية, مرتخية, METHOTREXATE,
# Nearest to على: في, نستخدم, والناجمة, البريتون, رصده, الكروية, من, لأجله,
# Nearest to عن: لوفاستاتين, المكونات, الرشح, تولبوتاميد, الرهبة, HBV, ثيروتروبين, بالجهاز,
# Nearest to ؟: ., والوزن, مختلف, حجمه, فيناسترايد, صال, تيترابينازين, البنسلين,
# Nearest to إلى: الى, في, من, مصحوب, SAPOFEN, الإبرة, Enalapril, عن,
# Nearest to لم: نشيطة, نافازولين, الملتويات, ث, بحقنه, الثعلب, التجاعيد, ",,
# Average loss at step  32000 :  11.774010473847389
# Average loss at step  34000 :  11.045589223146438
# Average loss at step  36000 :  9.549111602544784
# Average loss at step  38000 :  9.025712493538856
# Average loss at step  40000 :  8.56559666466713
# Nearest to علاج: reduction, أطر, لعيادة, النظر, التفاعلية, مساعدة, البريتون, هادئ,
# Nearest to منع: زوفران, الحملي, حينا, ثيروتروبين, والغدة, شانه, بين, ضافة,
# Nearest to و: وج, منقول, وضغطه, ب, صغار, لدحض, إكزيما, مثانية,
# Nearest to السلام: ومفاصل, كشفت, لويحات, معدية, للخطورة, إطلاقا, pericardium, MB,
# Nearest to تناول: استخدام, أوكسجين, ولذلك, الوصول, تساهم, كعب, Dr, ميثيل,
# Nearest to من: D8, في, بنسبة, أو, النيوميسين, الرجيع, زيبراسيدون, ..).,
# Nearest to ،: ,, ., )،, -, (, ), D9, –,
# Nearest to هذه: التي, الروماتوئيدي, بعض, لهل, الحلاقة, كريسماس, أربطة, ريتاربن,
# Nearest to الشهرية: تينوفوفير, Personality, البحار, نانوغرام, للديسليتر, خصوي, بالإعاضة, السيليسي,
# Nearest to مع: أو, في, البريتون, عن, بواسطة, امام, TNF, البروفسور,
# Nearest to بعد: قبل, عند, خلال, مستقبلا, أو, التمر, مرتخية, البريتون,
# Nearest to على: في, إلى, نستخدم, البريتون, لوفاستاتين, بالإعاضة, رصده, الكروية,
# Nearest to عن: لوفاستاتين, مع, المكونات, تولبوتاميد, HBV, قميص, الرشح, إلى,
# Nearest to ؟: ., :, ,, ،, يستخدمن, تلين, فيناسترايد, يشاركون,
# Nearest to إلى: الى, في, أو, على, SAPOFEN, مصحوب, مع, بشعركم,
# Nearest to لم: نشيطة, نافازولين, الملتويات, لا, والكلمات, ث, جماع, الثمينة,
# Average loss at step  42000 :  7.884022863745689
# Average loss at step  44000 :  7.639597211718559
# Average loss at step  46000 :  7.131673869609833
# Average loss at step  48000 :  6.524645415067673
# Average loss at step  50000 :  6.381486705780029
# Nearest to علاج: أطر, reduction, مساعدة, النظر, لعيادة, تساقط, التفاعلية, هادئ,
# Nearest to منع: زوفران, الحملي, حينا, والاستماع, ثيروتروبين, والغدة, شانه, للبيروكسيداز,
# Nearest to و: وج, ب, وضغطه, لدحض, منقول, توقفي, صغار, مثانية,
# Nearest to السلام: ومفاصل, كشفت, العربيات, لويحات, ونقلت, معدية, للخطورة, إطلاقا,
# Nearest to تناول: استخدام, بامكانهم, تساهم, أخذ, أوكسجين, الوصول, ولذلك, ميثيل,
# Nearest to من: النيوميسين, منها, D8, في, الرجيع, ومن, AstraZeneca, الخبيز,
# Nearest to ،: ,, ., )،, -, ), ؛, (, –,
# Nearest to هذه: التي, بعض, الروماتوئيدي, لهل, أربطة, الحلاقة, إمرأة, ريتاربن,
# Nearest to الشهرية: تينوفوفير, البحار, Personality, خصوي, نظن, حدوثها, نانوغرام, للديسليتر,
# Nearest to مع: أو, عن, في, TNF, البريتون, استراحات, بين, البروفسور,
# Nearest to بعد: قبل, عند, خلال, مستقبلا, أثناء, التمر, في, البريتون,
# Nearest to على: في, رصده, لوفاستاتين, الكروية, بالإعاضة, البريتون, نستخدم, ضعي,
# Nearest to عن: لوفاستاتين, مع, #, المكونات, HBV, تولبوتاميد, على, الرشح,
# Nearest to ؟: ., :, ,, !, ،, )., تلين, يستخدمن,
# Nearest to إلى: الى, في, على, SAPOFEN, عن, مع, وقسم, بشعركم,
# Nearest to لم: قد, لا, نشيطة, نافازولين, الملتويات, جماع, ث, الثمينة,
# Average loss at step  52000 :  6.2238915591239925
# Average loss at step  54000 :  5.816866590619087
# Average loss at step  56000 :  5.831336867213249
# Average loss at step  58000 :  5.587716374278068
# Average loss at step  60000 :  5.4909953950643535
# Nearest to علاج: أطر, لعيادة, النظر, اعراض, تساقط, معقد, مساعدة, reduction,
# Nearest to منع: زوفران, الحملي, وكتب, حينا, ثيروتروبين, والاستماع, ذات, للبيروكسيداز,
# Nearest to و: وج, ب, منقول, وضغطه, لدحض, أو, صغار, مثانية,
# Nearest to السلام: ومفاصل, كشفت, العربيات, لويحات, ونقلت, معدية, للخطورة, إطلاقا,
# Nearest to تناول: استخدام, أخذ, استهلاك, أوكسجين, بامكانهم, تساهم, Dr, فيناستريد,
# Nearest to من: منها, D8, بنسبة, AstraZeneca, الرجيع, الحكاية, ومن, نافاريلين,
# Nearest to ،: ,, ., )،, -, ), D9, ؛, –,
# Nearest to هذه: بعض, الروماتوئيدي, التي, أربطة, لهل, 796, الحلاقة, إمرأة,
# Nearest to الشهرية: تينوفوفير, نظن, البحار, Personality, خصوي, السيليسي, حدوثها, للديسليتر,
# Nearest to مع: أو, البريتون, في, الفتري, بواسطة, عن, عند, البروفسور,
# Nearest to بعد: قبل, عند, خلال, أثناء, حتى, مستقبلا, دون, منذ,
# Nearest to على: في, وعلى, الكروية, للجنسنج, رصده, البريتون, بالإعاضة, لوفاستاتين,
# Nearest to عن: لوفاستاتين, #, HBV, مع, المكونات, على, تولبوتاميد, الرهبة,
# Nearest to ؟: ., !, :, ,, ،, )., تلين, SAPOFEN,
# Nearest to إلى: الى, في, مع, SAPOFEN, والمسؤولة, على, Enalapril, فعادة,
# Nearest to لم: لا, قد, نشيطة, نافازولين, الملتويات, والكلمات, ELYZOL, جماع,
# Average loss at step  62000 :  5.40844773709774
# Average loss at step  64000 :  5.313701227903366
# Average loss at step  66000 :  4.9886634209156036
# Average loss at step  68000 :  4.977719234764576
# Average loss at step  70000 :  4.840249348938465
# Nearest to علاج: حالات, تشخيص, معالجة, أطر, تخفيف, تساقط, اعراض, لعيادة,
# Nearest to منع: الحملي, زوفران, وكتب, والاستماع, تكوينه, حينا, للبيروكسيداز, ثيروتروبين,
# Nearest to و: وج, ب, وضغطه, منقول, (, مثانية, لدحض, الفرن,
# Nearest to السلام: ومفاصل, العربيات, كشفت, لويحات, ونقلت, معدية, للخطورة, بأس,
# Nearest to تناول: استخدام, استهلاك, أخذ, تزحف, بامكانهم, أوكسجين, بتناول, استعمال,
# Nearest to من: منها, البامية, AstraZeneca, النيوميسين, بنسبة, D8, Dr, بانكوست,
# Nearest to ،: ,, ., )،, ؛, ), D9, –, الإنكار,
# Nearest to هذه: بعض, التي, الروماتوئيدي, أربطة, 796, لهل, لهذه, سنها,
# Nearest to الشهرية: تينوفوفير, نظن, البحار, Personality, خصوي, حدوثها, السيليسي, المجهول,
# Nearest to مع: أو, بواسطة, البريتون, الفتري, بسبب, استراحات, عربة, بسوء,
# Nearest to بعد: قبل, عند, خلال, أثناء, منذ, دون, حتى, مستقبلا,
# Nearest to على: في, الكروية, وعلى, ذو, الإيقاع, البريتون, للجنسنج, كيبرا,
# Nearest to عن: لوفاستاتين, #, HBV, مع, الرهبة, ثيروتروبين, حول, تدفئة,
# Nearest to ؟: ., !, :, ,, ،, )., البامية, :**,
# Nearest to إلى: الى, مع, في, على, فعادة, للزوجة, Enalapril, لمشكلة,
# Nearest to لم: لا, قد, نشيطة, عندما, المداعبة, نافازولين, الملتويات, ELYZOL,
# Average loss at step  72000 :  5.13003149652481
# Average loss at step  74000 :  5.0037911306619645
# Average loss at step  76000 :  4.836411011815071
# Average loss at step  78000 :  4.799215122938156
# Average loss at step  80000 :  4.766758198738098
# Nearest to علاج: تشخيص, أطر, معالجة, تساقط, تخفيف, النظر, حفل, حالات,
# Nearest to منع: الحملي, زوفران, تكوينه, والاستماع, وكتب, للبيروكسيداز, حينا, للتوضيح,
# Nearest to و: وج, ب, أو, منقول, وضغطه, مثانية, صغار, لدحض,
# Nearest to السلام: ومفاصل, العربيات, كشفت, لويحات, ونقلت, للخطورة, معدية, مطبخك,
# Nearest to تناول: استخدام, استهلاك, أخذ, شرب, بتناول, تزحف, أوكسجين, AST,
# Nearest to من: منها, البامية, بنسبة, AstraZeneca, D8, ومن, الرجيع, KEPPRA,
# Nearest to ،: ,, ., )،, -, D9, –, ؛, ),
# Nearest to هذه: بعض, الروماتوئيدي, 796, لهل, أربطة, التي, لهذه, كبة,
# Nearest to الشهرية: تينوفوفير, نظن, البحار, Personality, خصوي, السيليسي, المجهول, حدوثها,
# Nearest to مع: أو, بسبب, البريتون, عند, بواسطة, لأن, الفتري, بسوء,
# Nearest to بعد: قبل, عند, أثناء, خلال, منذ, مستقبلا, التمر, وبعد,
# Nearest to على: وعلى, في, البريتون, الإيقاع, للجنسنج, رصده, ذو, نستخدم,
# Nearest to عن: لوفاستاتين, HBV, حول, #, بسبب, ثيروتروبين, مع, الرهبة,
# Nearest to ؟: ., !, :, ,, )., البامية, ،, روبينيرول,
# Nearest to إلى: الى, في, فعادة, مع, \., SAPOFEN, للزوجة, أو,
# Nearest to لم: لا, قد, نشيطة, عندما, ELYZOL, نافازولين, المداعبة, الملتويات,
# Average loss at step  82000 :  4.7728483134508135
# Average loss at step  84000 :  4.758856452584267
# Average loss at step  86000 :  4.5859814800024035
# Average loss at step  88000 :  3.650651126921177
# Average loss at step  90000 :  4.148549480646849
# Nearest to علاج: معالجة, تشخيص, أطر, حالات, INDERAL, تساقط, اعراض, حفل,
# Nearest to منع: الحملي, لمنع, والاستماع, زوفران, وكتب, للتوضيح, للبيروكسيداز, تكوينه,
# Nearest to و: ب, وج, أو, منقول, مثانية, توقفي, وضغطه, الاستعانه,
# Nearest to السلام: ومفاصل, العربيات, كشفت, لويحات, ونقلت, الإستروجينات, معدية, الديبيرون,
# Nearest to تناول: استخدام, استهلاك, أخذ, بتناول, شرب, اختيار, بامكانهم, تزحف,
# Nearest to من: منها, بنسبة, البامية, باكورة, ضد, رولز, D8, الإنكار,
# Nearest to ،: ,, )،, ., ), ؛, –, D9, بالتأثير,
# Nearest to هذه: بعض, 796, الروماتوئيدي, لهذه, لهل, أربطة, التي, هذا,
# Nearest to الشهرية: تينوفوفير, نظن, البحار, خصوي, أتلقى, السيليسي, Personality, المجهول,
# Nearest to مع: أو, البريتون, بسبب, لأن, بواسطة, بسوء, دون, TNF,
# Nearest to بعد: قبل, عند, أثناء, خلال, منذ, وبعد, مستقبلا, يمكن,
# Nearest to على: وعلى, في, الكروية, الإيقاع, نستخدم, للجنسنج, بالكوسى, بالإعاضة,
# Nearest to عن: لوفاستاتين, حول, بسبب, HBV, #, ثيروتروبين, الرهبة, للحدوث,
# Nearest to ؟: ., !, ,, :, )., البامية, روبينيرول, حدث,
# Nearest to إلى: الى, مع, لمشكلة, فعادة, \., في, SAPOFEN, الكارني,
# Nearest to لم: لا, قد, نشيطة, عندما, ELYZOL, المداعبة, ولا, الملتويات,
# Average loss at step  92000 :  8.330926989316941
# Average loss at step  94000 :  7.5088763825893405
# Average loss at step  96000 :  6.635554099917412
# Average loss at step  98000 :  6.927020242512226
# Average loss at step  100000 :  6.284333685040474
# Nearest to علاج: معالجة, أطر, الراس, حفل, INDERAL, تشخيص, النظر, اعراض,
# Nearest to منع: لمنع, وكتب, تكوينه, , الحملي, للرؤوس, والاستماع, زوفران,
# Nearest to و: ؟,, , أو, INDERAL, UNK, المفاغرة, إستمرت, ب,
# Nearest to السلام: , pericardium, ومفاصل, نومهم, إيتون, ونقلت, ريامسينولون, طب,
# Nearest to تناول: استخدام, استهلاك, أخذ, استعمال, بتناول, شرب, اختيار, فوسينوبريل,
# Nearest to من: منها, بنسبة, في, البامية, مغص, منه, مقارنه, باكورة,
# Nearest to ،: ;, ,, )،, ., ؟, ؛, ), D9,
# Nearest to هذه: بعض, 796, لهذه, أربطة, جميع, الروماتوئيدي, التي, تلك,
# Nearest to الشهرية: تينوفوفير, , البحار, خصوي, نظن, أتلقى, السيليسي, أمورولفين,
# Nearest to مع: عند, دون, البريتون, بسبب, أو, بسوء, او, بواسطة,
# Nearest to بعد: قبل, عند, أثناء, خلال, منذ, دون, حتى, مستقبلا,
# Nearest to على: في, وعلى, الإيقاع, للجنسنج, المعثكلة, عن, الكروية, والرغبات,
# Nearest to عن: لوفاستاتين, بسبب, حول, قميص, HBV, لتحديد, على, #,
# Nearest to ؟: !, ., ,, ،, البامية, روبينيرول, ؟!, حدث,
# Nearest to إلى: الى, أو, في, دون, فعادة, D9, \., من,
# Nearest to لم: لا, قد, ولم, عندما, حتى, نشيطة, ELYZOL, كنت,
# Average loss at step  102000 :  6.118289143919945
# Average loss at step  104000 :  5.517218022227287
# Average loss at step  106000 :  6.283893917143345
# Average loss at step  108000 :  5.622856722474098
# Average loss at step  110000 :  5.836547742962837
# Nearest to علاج: الراس, حفل, معالجة, تشخيص, سبب, العلاج, INDERAL, أطر,
# Nearest to منع: لمنع, تكوينه, وكتب, والغلوكاغون, الفلوس, مشارك, للرؤوس, الحملي,
# Nearest to و: ؟,, UNK, , أو, ولكن, المفاغرة, او, ßßo,
# Nearest to السلام: طب, ورحمة, ريامسينولون, إيتون, , الثلاجه, وبالله, 2016,
# Nearest to تناول: استخدام, استهلاك, أخذ, شرب, استعمال, بتناول, اختيار, وتناول,
# Nearest to من: منها, في, بنسبة, البامية, منه, عمره, مغص, مقارنه,
# Nearest to ،: ;, ,, )،, ً،, ؛, ., ؟, ),
# Nearest to هذه: بعض, تلك, لهذه, 796, جميع, لهل, هذا, أربطة,
# Nearest to الشهرية: تينوفوفير, , خصوي, البحار, أتلقى, السيليسي, نظن, المجهول,
# Nearest to مع: عند, البريتون, دون, او, بسبب, إستمرت, بسوء, لأن,
# Nearest to بعد: قبل, عند, أثناء, منذ, خلال, دون, للقشرة, حتى,
# Nearest to على: في, وعلى, الإيقاع, المعثكلة, عن, لتوضح, نابض, حول,
# Nearest to عن: لوفاستاتين, After, بسبب, HBV, حول, قميص, تولبوتاميد, لتحديد,
# Nearest to ؟: !, ., ,, ،, ؟!, البامية, After, ..,
# Nearest to إلى: الى, في, دون, فعادة, من, على, D9, والمسؤولة,
# Nearest to لم: ولم, لا, قد, عندما, حتى, كنت, نشيطة, ELYZOL,
# Average loss at step  112000 :  5.920552897453308
# Average loss at step  114000 :  5.8078626276254655
# Average loss at step  116000 :  5.615603539466858
# Average loss at step  118000 :  5.136683139204979
# Average loss at step  120000 :  4.897578201830387
# Nearest to علاج: الراس, معالجة, حفل, لعلاج, دواء, اعراض, سبب, العلاج,
# Nearest to منع: لمنع, تكوينه, والغلوكاغون, وكتب, الفلوس, مشارك, , للرؤوس,
# Nearest to و: ؟,, او, أو, , UNK, المفاغرة, إستمرت, ولكن,
# Nearest to السلام: ورحمة, وبالله, طب, الله, عليكم, إيتون, ريامسينولون, ,
# Nearest to تناول: استخدام, أخذ, استهلاك, استعمال, بتناول, شرب, اختيار, وتناول,
# Nearest to من: منها, البامية, الخلط, منه, بنسبة, في, ضاب, مغص,
# Nearest to ،: ;, ,, )،, ؛, ., ), ؟, ً،,
# Nearest to هذه: تلك, بعض, لهذه, لهل, نفس, 796, هذا, جميع,
# Nearest to الشهرية: تينوفوفير, , خصوي, الدموية, منتظمة, البحار, السيليسي, أتلقى,
# Nearest to مع: عند, او, البريتون, دون, إستمرت, لأن, بسوء, أو,
# Nearest to بعد: قبل, عند, أثناء, خلال, منذ, دون, وبعد, حتى,
# Nearest to على: وعلى, في, الإيقاع, فى, علي, نابض, المعثكلة, عليها,
# Nearest to عن: لوفاستاتين, After, HBV, بسبب, حول, لتحديد, للحدوث, بحثية,
# Nearest to ؟: !, ., ,, ،, ؟!, .., ..., ;,
# Nearest to إلى: الى, واختبار, فعادة, والفوليك, في, لمشكلة, المتضيق, والمسؤولة,
# Nearest to لم: ولم, لا, عندما, حتى, قد, كنت, نشيطة, ELYZOL,
# Average loss at step  122000 :  5.131607041478157
# Average loss at step  124000 :  5.172792550086975
# Average loss at step  126000 :  4.888862544417381
# Average loss at step  128000 :  4.850829812645912
# Average loss at step  130000 :  4.697506110966206
# Nearest to علاج: معالجة, لعلاج, دواء, الراس, العلاج, حفل, سبب, تشخيص,
# Nearest to منع: لمنع, تكوينه, والغلوكاغون, ماالعلاج, 582, مشارك, وكتب, للرؤوس,
# Nearest to و: او, ؟,, UNK, أو, ولكن, باليبيريدون, , وكذلك,
# Nearest to السلام: ورحمة, وبالله, عليكم, ريامسينولون, إيتون, __غرد, 2016, طب,
# Nearest to تناول: استخدام, استهلاك, أخذ, استعمال, شرب, بتناول, وتناول, اختيار,
# Nearest to من: منها, في, بنسبة, الريسبردال, منه, مقارنه, AstraZeneca, البامية,
# Nearest to ،: ;, ,, )،, ؛, ., ً،, ), !,
# Nearest to هذه: تلك, بعض, لهذه, جميع, نفس, 796, لهل, هذا,
# Nearest to الشهرية: تينوفوفير, منتظمة, الدموية, , خصوي, السيليسي, البحار, المجهول,
# Nearest to مع: عند, او, البريتون, دون, بسوء, بسبب, إستمرت, بدون,
# Nearest to بعد: قبل, عند, أثناء, خلال, منذ, وبعد, دون, حتى,
# Nearest to على: وعلى, في, علي, الإيقاع, عليها, فى, نابض, المعثكلة,
# Nearest to عن: لوفاستاتين, حول, After, بسبب, HBV, لتحديد, بخصوص, قميص,
# Nearest to ؟: !, ., ,, ؟!, ،, ..., .., ؟؟,
# Nearest to إلى: الى, والفوليك, وظواهر, فعادة, لمشكلة, بمتطلبات, والمسؤولة, وقسم,
# Nearest to لم: ولم, لا, عندما, قد, حتى, كنت, ELYZOL, نشيطة,
# Average loss at step  132000 :  4.440906785368919
# Average loss at step  134000 :  4.557013090729713
# Average loss at step  136000 :  4.217882729053497
# Average loss at step  138000 :  4.037179679274559
# Average loss at step  140000 :  5.03483625793457
# Nearest to علاج: دواء, لعلاج, معالجة, الراس, حفل, العلاج, سبب, INDERAL,
# Nearest to منع: لمنع, تكوينه, والغلوكاغون, ماالعلاج, مشارك, 582, للرؤوس, وكتب,
# Nearest to و: ؟,, او, UNK, , الامان, ولكن, باليبيريدون, أو,
# Nearest to السلام: ورحمة, وبالله, عليكم, __غرد, إيتون, ريامسينولون, الله, 2016,
# Nearest to تناول: استخدام, أخذ, استهلاك, استعمال, شرب, بتناول, وتناول, اختيار,
# Nearest to من: منها, منه, الريسبردال, البامية, يقتل, مقارنه, ß, في,
# Nearest to ،: ;, ,, )،, ., ؛, !, ؟, ً،,
# Nearest to هذه: تلك, بعض, لهذه, نفس, جميع, لهل, هذا, 796,
# Nearest to الشهرية: منتظمة, تينوفوفير, الدموية, , خصوي, السيليسي, المجهول, البحار,
# Nearest to مع: عند, او, بسوء, البريتون, دون, أو, إستمرت, بواسطة,
# Nearest to بعد: قبل, عند, خلال, أثناء, منذ, وبعد, للقشرة, After,
# Nearest to على: وعلى, علي, في, الإيقاع, عليها, بالحيض, عليه, المعثكلة,
# Nearest to عن: لوفاستاتين, HBV, After, لتحديد, بسبب, حول, قميص, بخصوص,
# Nearest to ؟: !, ،, ؟!, ., ,, ؟؟, ..., توفو,
# Nearest to إلى: الى, والفوليك, وظواهر, بمتطلبات, في, فعادة, المتضيق, والمسؤولة,
# Nearest to لم: ولم, لا, عندما, حتى, كنت, قد, ELYZOL, والماكولات,
# Average loss at step  142000 :  4.320817759394646
# Average loss at step  144000 :  4.80291636800766
# Average loss at step  146000 :  4.258127240121365
# Average loss at step  148000 :  4.473065194129944
# Average loss at step  150000 :  4.235179379463196
# Nearest to علاج: لعلاج, دواء, معالجة, الراس, حفل, اعراض, سبب, العلاج,
# Nearest to منع: لمنع, تكوينه, والغلوكاغون, 582, لحدوث, للرؤوس, ماالعلاج, مشارك,
# Nearest to و: ؟,, او, UNK, ولكن, , المفاغرة, سليمتين, منقول,
# Nearest to السلام: ورحمة, وبالله, عليكم, __غرد, إيتون, الله, بسم, ريامسينولون,
# Nearest to تناول: استخدام, أخذ, استعمال, استهلاك, شرب, بتناول, وتناول, اختيار,
# Nearest to من: منها, منه, بنسبة, الريسبردال, بالشوكلاته, مقارنه, النيوميسين, في,
# Nearest to ،: ;, ,, )،, ؛, ., ً،, !, ؟,
# Nearest to هذه: تلك, بعض, لهذه, نفس, جميع, 796, أربطة, هذا,
# Nearest to الشهرية: الدموية, منتظمة, تينوفوفير, , خصوي, اثاء, السيليسي, الدورة,
# Nearest to مع: عند, او, بسوء, البريتون, بدون, دون, إستمرت, وعند,
# Nearest to بعد: قبل, عند, أثناء, خلال, منذ, وبعد, للقشرة, حتى,
# Nearest to على: وعلى, علي, عليها, الإيقاع, في, نابض, المعثكلة, اصناف,
# Nearest to عن: لوفاستاتين, بسبب, HBV, After, لتحديد, قميص, حول, بخصوص,
# Nearest to ؟: !, ؟!, ؟؟, ،, ., ,, توفو, البامية,
# Nearest to إلى: الى, والفوليك, المتضيق, في, D9, تفكيرهم, والمسؤولة, فعادة,
# Nearest to لم: ولم, لا, عندما, قد, كنت, حتى, سوف, ELYZOL,
# Average loss at step  152000 :  4.547077039837837
# Average loss at step  154000 :  4.18429997074604
# Average loss at step  156000 :  4.359490697205067
# Average loss at step  158000 :  4.2788761292696
# Average loss at step  160000 :  4.193562417566776
# Nearest to علاج: لعلاج, دواء, معالجة, العلاج, حفل, النظر, الراس, تشخيص,
# Nearest to منع: لمنع, تكوينه, لحدوث, غامض, والغلوكاغون, ماالعلاج, 582, للرؤوس,
# Nearest to و: او, ؟,, وكذلك, UNK, ولكن, , المفاغرة, باليبيريدون,
# Nearest to السلام: ورحمة, وبالله, عليكم, __غرد, بسم, إيتون, الله, الموفق,
# Nearest to تناول: أخذ, استخدام, استعمال, استهلاك, شرب, بتناول, وتناول, اختيار,
# Nearest to من: منها, منه, ومن, مغص, ضاب, فالواقع, وسيرشدك, البامية,
# Nearest to ،: ;, ,, )،, ؛, ., !, ً،, ؟,
# Nearest to هذه: تلك, بعض, نفس, لهذه, جميع, هذا, لهل, 796,
# Nearest to الشهرية: الدموية, منتظمة, تينوفوفير, , خصوي, اثاء, السيليسي, الإنكار,
# Nearest to مع: عند, او, ومع, بسوء, البريتون, أصفر, دون, وعند,
# Nearest to بعد: قبل, عند, أثناء, خلال, وبعد, للقشرة, منذ, دون,
# Nearest to على: وعلى, علي, في, عليها, الإيقاع, المعثكلة, نابض, عليه,
# Nearest to عن: لوفاستاتين, بسبب, HBV, حول, بخصوص, لتحديد, للحدوث, After,
# Nearest to ؟: !, ؟!, ؟؟, ,, ،, ., ..., ..,
# Nearest to إلى: الى, والفوليك, المتضيق, تفكيرهم, والمسؤولة, سفرة, D9, وظواهر,
# Nearest to لم: ولم, عندما, لا, كنت, سوف, حتى, والماكولات, ELYZOL,
# Average loss at step  162000 :  4.334910279452801
# Average loss at step  164000 :  4.205116401016713
# Average loss at step  166000 :  4.228056326150894
# Average loss at step  168000 :  4.12705567908287
# Average loss at step  170000 :  4.132916761934757
# Nearest to علاج: دواء, لعلاج, معالجة, العلاج, اعراض, سبب, الراس, حفل,
# Nearest to منع: لمنع, تكوينه, غامض, والغلوكاغون, لحدوث, للبيروكسيداز, ماالعلاج, للرؤوس,
# Nearest to و: او, ؟,, UNK, وكذلك, ولكن, أو, باليبيريدون, ,
# Nearest to السلام: ورحمة, وبالله, بسم, __غرد, عليكم, الموفق, نسأل, إيتون,
# Nearest to تناول: أخذ, استخدام, استعمال, استهلاك, شرب, بتناول, وتناول, اختيار,
# Nearest to من: منها, منه, بالشوكلاته, الريسبردال, مغص, البامية, السبابه, مقارنه,
# Nearest to ،: ;, )،, ,, ., ؛, !, ً،, ؟,
# Nearest to هذه: تلك, لهذه, بعض, نفس, جميع, وهذه, هذا, لهل,
# Nearest to الشهرية: الدموية, منتظمة, تينوفوفير, , اثاء, خصوي, السيليسي, الإنكار,
# Nearest to مع: عند, ومع, او, وعند, البريتون, بواسطة, بسوء, بدون,
# Nearest to بعد: قبل, عند, خلال, أثناء, منذ, وبعد, وعند, للقشرة,
# Nearest to على: وعلى, علي, الإيقاع, عليها, في, عليه, نابض, ينقذ,
# Nearest to عن: لوفاستاتين, بسبب, حول, بخصوص, HBV, لتحديد, After, للحدوث,
# Nearest to ؟: !, ؟!, ؟؟, ،, ., ,, توفو, ...,
# Nearest to إلى: الى, والفوليك, المتضيق, تفكيرهم, والمسؤولة, وظواهر, سفرة, في,
# Nearest to لم: ولم, عندما, لا, كنت, سوف, والماكولات, لن, حتى,
# Average loss at step  172000 :  4.33196435546875
# Average loss at step  174000 :  4.322370361149311
# Average loss at step  176000 :  4.153811255574227
# Average loss at step  178000 :  4.202850298523903
# Average loss at step  180000 :  4.23448809671402
# Nearest to علاج: لعلاج, دواء, معالجة, العلاج, اعراض, الراس, حفل, تشخيص,
# Nearest to منع: لمنع, لحدوث, غامض, والغلوكاغون, تكوينه, للبيروكسيداز, ماالعلاج, للرؤوس,
# Nearest to و: او, ؟,, وكذلك, Mono, باليبيريدون, ولكن, , المفاغرة,
# Nearest to السلام: ورحمة, وبالله, بسم, عليكم, __غرد, الموفق, عضو, نسأل,
# Nearest to تناول: استخدام, أخذ, استعمال, استهلاك, شرب, بتناول, وتناول, اختيار,
# Nearest to من: منها, منه, البامية, روعة, مغص, في, بالشوكلاته, KEPPRA,
# Nearest to ،: ;, ,, )،, !, ., ؛, ً،, ؟,
# Nearest to هذه: تلك, لهذه, نفس, بعض, جميع, وهذه, هذا, لهل,
# Nearest to الشهرية: الدموية, منتظمة, تينوفوفير, اثاء, , خصوي, السيليسي, الإنكار,
# Nearest to مع: عند, ومع, البريتون, مثلا, وعند, إستمرت, بسوء, بالفريك,
# Nearest to بعد: قبل, عند, أثناء, وبعد, وعند, خلال, منذ, للقشرة,
# Nearest to على: وعلى, علي, عليها, الإيقاع, في, عليه, المعثكلة, بالحيض,
# Nearest to عن: لوفاستاتين, بسبب, HBV, بخصوص, عنها, حول, After, قميص,
# Nearest to ؟: !, ؟!, ؟؟, ., ،, ,, ..., توفو,
# Nearest to إلى: الى, والفوليك, والمسؤولة, المتضيق, سفرة, وظواهر, D9, تفكيرهم,
# Nearest to لم: ولم, عندما, لا, سوف, كنت, لن, حتى, والماكولات,
# Average loss at step  182000 :  4.079177868723869
# Average loss at step  184000 :  4.143436773002148
# Average loss at step  186000 :  3.847655557334423
# Average loss at step  188000 :  4.199176174402237
# Average loss at step  190000 :  4.206878651857376
# Nearest to علاج: لعلاج, دواء, معالجة, تشخيص, العلاج, اعراض, سبب, الراس,
# Nearest to منع: لمنع, لحدوث, غامض, والغلوكاغون, تكوينه, للبيروكسيداز, ماالعلاج, للرؤوس,
# Nearest to و: او, ؟,, وكذلك, ولكن, باليبيريدون, المفاغرة, Mono, ,
# Nearest to السلام: ورحمة, وبالله, بسم, الموفق, عضو, عليكم, __غرد, نسأل,
# Nearest to تناول: استخدام, أخذ, استعمال, استهلاك, شرب, بتناول, وتناول, اختيار,
# Nearest to من: منها, منه, السبابه, البامية, KEPPRA, باكورة, روعة, يتمي,
# Nearest to ،: ;, ,, ., )،, !, ؛, ً،, ß,
# Nearest to هذه: تلك, لهذه, نفس, وهذه, بعض, جميع, هذا, لهل,
# Nearest to الشهرية: الدموية, منتظمة, تينوفوفير, اثاء, , خصوي, الإنكار, السيليسي,
# Nearest to مع: عند, ومع, البريتون, اخرئ, وعند, إستمرت, بسوء, او,
# Nearest to بعد: قبل, عند, وعند, وبعد, أثناء, منذ, دون, خلال,
# Nearest to على: علي, وعلى, المعثكلة, عليها, الإيقاع, عليه, في, بالحيض,
# Nearest to عن: بسبب, لوفاستاتين, بخصوص, حول, عنها, HBV, After, عنه,
# Nearest to ؟: ؟!, !, ؟؟, ., ،, ...., ,, توفو,
# Nearest to إلى: الى, والفوليك, الي, المتضيق, والمسؤولة, بمتطلبات, لمشكلة, D9,
# Nearest to لم: ولم, عندما, لا, سوف, لن, كنت, والماكولات, حتى,
# Average loss at step  192000 :  3.789325870156288
# Average loss at step  194000 :  4.033213224768638
# Average loss at step  196000 :  3.9379671797156335
# Average loss at step  198000 :  4.03746427154541
# Average loss at step  200000 :  3.89503025251627
# Nearest to علاج: دواء, لعلاج, معالجة, العلاج, تشخيص, اعراض, الراس, سبب,
# Nearest to منع: لمنع, لحدوث, غامض, والغلوكاغون, تكوينه, للبيروكسيداز, , للرؤوس,
# Nearest to و: او, ؟,, الامان, وكذلك, المساحة, , المفاغرة, فـ,
# Nearest to السلام: وبالله, ورحمة, بسم, عضو, الموفق, __غرد, عليكم, نسأل,
# Nearest to تناول: أخذ, استخدام, استعمال, استهلاك, شرب, بتناول, وتناول, اختيار,
# Nearest to من: منها, منه, روعة, ومن, الريسبردال, تأخذينه, مغص, السبابه,
# Nearest to ،: ;, )،, ,, !, ً،, ., ؛, D9,
# Nearest to هذه: تلك, نفس, لهذه, هذا, وهذه, جميع, بعض, لهل,
# Nearest to الشهرية: الدموية, منتظمة, تينوفوفير, اثاء, خصوي, القادمة, , الإنكار,
# Nearest to مع: عند, ومع, وعند, أصفر, بسوء, البريتون, اخرئ, بدون,
# Nearest to بعد: قبل, عند, وبعد, وعند, أثناء, منذ, دون, ولمدى,
# Nearest to على: علي, وعلى, عليها, الإيقاع, عليه, المعثكلة, في, المتدنية,
# Nearest to عن: لوفاستاتين, بسبب, بخصوص, HBV, حول, عنها, After, نخشى,
# Nearest to ؟: ؟!, !, ؟؟, ...., ., ،, توفو, ...,
# Nearest to إلى: الى, والفوليك, الي, المتضيق, والمسؤولة, لمشكلة, بمتطلبات, وظواهر,
# Nearest to لم: ولم, عندما, سوف, لا, لن, كنت, والماكولات, قد,
# Average loss at step  202000 :  4.676153321027756
# Average loss at step  204000 :  4.067711895883083
# Average loss at step  206000 :  3.8560231644511225
# Average loss at step  208000 :  4.055740998804569
# Average loss at step  210000 :  3.954687353014946
# Nearest to علاج: لعلاج, دواء, معالجة, العلاج, تشخيص, اعراض, حفل, سبب,
# Nearest to منع: لمنع, لحدوث, غامض, والغلوكاغون, تكوينه, للبيروكسيداز, ماالعلاج, للرؤوس,
# Nearest to و: او, ؟,, UNK, وكذلك, باليبيريدون, Mono, , الامان,
# Nearest to السلام: وبالله, ورحمة, عضو, بسم, الموفق, نسأل, __غرد, عليكم,
# Nearest to تناول: أخذ, استعمال, استخدام, استهلاك, شرب, بتناول, وتناول, اختيار,
# Nearest to من: منها, السبابه, بالشوكلاته, منه, ومن, المكونه, الريسبردال, روعة,
# Nearest to ،: ;, ,, )،, !, ؛, ., ً،, ؟,
# Nearest to هذه: تلك, نفس, لهذه, بعض, وهذه, جميع, هذا, لهل,
# Nearest to الشهرية: الدموية, منتظمة, تينوفوفير, اثاء, القادمة, , خصوي, الإنكار,
# Nearest to مع: ومع, عند, وعند, فالشاي, بسوء, البريتون, إستمرت, وبين,
# Nearest to بعد: قبل, عند, وعند, وبعد, أثناء, خلال, منذ, ولمدى,
# Nearest to على: علي, وعلى, عليها, الإيقاع, في, عليه, المعثكلة, الأكيد,
# Nearest to عن: لوفاستاتين, بسبب, بخصوص, عنها, حول, HBV, After, عنه,
# Nearest to ؟: ؟!, ؟؟, !, ،, ., توفو, ...., ,,
# Nearest to إلى: الى, والفوليك, الي, والمسؤولة, سفرة, وظواهر, بمتطلبات, twice,
# Nearest to لم: ولم, عندما, سوف, لا, لن, كنت, حتى, قد,
# Average loss at step  212000 :  3.707644420385361
# Average loss at step  214000 :  4.004757021665573
# Average loss at step  216000 :  3.8682393875718115
# Average loss at step  218000 :  4.00091127961874
# Average loss at step  220000 :  3.763656236112118
# Nearest to علاج: لعلاج, دواء, معالجة, العلاج, تشخيص, سبب, اعراض, الراس,
# Nearest to منع: لمنع, لحدوث, غامض, والغلوكاغون, للبيروكسيداز, تكوينه, حدوث, ماالعلاج,
# Nearest to و: او, ؟,, وكذلك, UNK, باليبيريدون, Mono, ولكن, ,
# Nearest to السلام: ورحمة, وبالله, بسم, عضو, الموفق, نسأل, __غرد, الأخت,
# Nearest to تناول: أخذ, استعمال, استخدام, استهلاك, شرب, وتناول, بتناول, اختيار,
# Nearest to من: منها, منه, ومن, روعة, البامية, بالشوكلاته, السبابه, وسيرشدك,
# Nearest to ،: ;, ,, )،, !, ., ؛, ً،, -،,
# Nearest to هذه: تلك, لهذه, نفس, هذا, وهذه, بعض, جميع, لهل,
# Nearest to الشهرية: الدموية, منتظمة, تينوفوفير, القادمة, اثاء, , الإنكار, خصوي,
# Nearest to مع: ومع, عند, وعند, إستمرت, البريتون, اخرئ, بسوء, وبين,
# Nearest to بعد: قبل, عند, وعند, وبعد, أثناء, منذ, خلال, ولمدى,
# Nearest to على: وعلى, علي, عليها, الإيقاع, المعثكلة, في, عليه, الكروية,
# Nearest to عن: لوفاستاتين, بخصوص, HBV, عنها, بسبب, حول, عنه, After,
# Nearest to ؟: ؟!, ؟؟, !, ...., ., ,, توفو, ،,
# Nearest to إلى: الى, والفوليك, الي, إلي, D9, لمشكلة, وظواهر, تفكيرهم,
# Nearest to لم: ولم, عندما, سوف, لا, لن, كنت, حتى, قد,
# Average loss at step  222000 :  3.9424521472454073
# Average loss at step  224000 :  3.800899950027466
# Average loss at step  226000 :  3.98878104031086
# Average loss at step  228000 :  3.9945142887830736
# Average loss at step  230000 :  3.6493639920949934
# Nearest to علاج: لعلاج, دواء, معالجة, تشخيص, العلاج, اعراض, سبب, الراس,
# Nearest to منع: لمنع, لحدوث, غامض, , الثرمبوبلاستين, والغلوكاغون, SAPOFEN, للبيروكسيداز,
# Nearest to و: او, ؟,, وكذلك, Mono, المفاغرة, UNK, ولكن, باليبيريدون,
# Nearest to السلام: ورحمة, وبالله, بسم, الموفق, عضو, سلام, نسأل, __غرد,
# Nearest to تناول: أخذ, استعمال, استخدام, استهلاك, شرب, بتناول, وتناول, اختيار,
# Nearest to من: منها, منه, السبابه, ومن, الريسبردال, البامية, KEPPRA, مقارنه,
# Nearest to ،: ;, ,, )،, ., !, ؛, ؟, ً،,
# Nearest to هذه: تلك, نفس, لهذه, بعض, هذا, وهذه, جميع, لهل,
# Nearest to الشهرية: الدموية, منتظمة, تينوفوفير, اثاء, القادمة, , الإنكار, خصوي,
# Nearest to مع: ومع, عند, وعند, البريتون, إستمرت, وبين, بسوء, رغم,
# Nearest to بعد: قبل, عند, وعند, وبعد, منذ, أثناء, فلوريد, دون,
# Nearest to على: علي, وعلى, عليها, المعثكلة, الإيقاع, عليه, بإرجاء, في,
# Nearest to عن: لوفاستاتين, عنها, بسبب, بخصوص, HBV, عنه, حول, قميص,
# Nearest to ؟: ؟!, ؟؟, !, ،, ., ...., ,, ...,
# Nearest to إلى: الى, والفوليك, الي, إلي, D9, والمسؤولة, وظواهر, تفكيرهم,
# Nearest to لم: ولم, عندما, سوف, لا, كنت, لن, والماكولات, فلم,
# Average loss at step  232000 :  3.675427967786789
# Average loss at step  234000 :  3.739965891003609
# Average loss at step  236000 :  3.6844488864541054
# Average loss at step  238000 :  3.9502613654732706
# Average loss at step  240000 :  3.7690846680402754
# Nearest to علاج: لعلاج, معالجة, دواء, تشخيص, العلاج, سبب, حفل, الراس,
# Nearest to منع: لمنع, لحدوث, غامض, تنظيم, والغلوكاغون, للبيروكسيداز, الثرمبوبلاستين, ,
# Nearest to و: او, ؟,, وكذلك, Mono, UNK, باليبيريدون, ولكن, للذكور,
# Nearest to السلام: ورحمة, بسم, وبالله, الموفق, عضو, نسأل, سلام, __غرد,
# Nearest to تناول: أخذ, استعمال, استخدام, استهلاك, شرب, وتناول, اختيار, بتناول,
# Nearest to من: منها, ومن, المكونه, الريسبردال, منه, روعة, بالشوكلاته, البامية,
# Nearest to ،: ;, ,, )،, ., ؛, ً،, !, D9,
# Nearest to هذه: تلك, لهذه, نفس, بعض, وهذه, جميع, هذا, لهل,
# Nearest to الشهرية: الدموية, منتظمة, تينوفوفير, , القادمة, اثاء, الإنكار, الدورة,
# Nearest to مع: ومع, عند, وعند, البريتون, فالشاي, وبين, إستمرت, بسوء,
# Nearest to بعد: قبل, عند, وعند, وبعد, فلوريد, منذ, أثناء, ولمدى,
# Nearest to على: علي, وعلى, عليها, الإيقاع, المعثكلة, عليه, في, لتوضح,
# Nearest to عن: لوفاستاتين, بسبب, بخصوص, عنها, حول, After, لتحديد, HBV,
# Nearest to ؟: ؟!, ؟؟, !, ., ...., توفو, ،, ...,
# Nearest to إلى: الى, والفوليك, الي, إلي, والمسؤولة, D9, إليها, وظواهر,
# Nearest to لم: ولم, عندما, لا, سوف, كنت, لن, فلم, والماكولات,
# Average loss at step  242000 :  3.927434075117111
# Average loss at step  244000 :  3.768026584506035
# Average loss at step  246000 :  3.8830543986558914
# Average loss at step  248000 :  3.7014136271476747
# Average loss at step  250000 :  3.6352198496460915
# Nearest to علاج: لعلاج, معالجة, دواء, العلاج, تشخيص, علاجها, Metoprolol, سبب,
# Nearest to منع: لمنع, لحدوث, غامض, تأجيل, للبيروكسيداز, والغلوكاغون, , الثرمبوبلاستين,
# Nearest to و: او, وكذلك, UNK, ؟,, Mono, فـ, فالح, منقول,
# Nearest to السلام: ورحمة, وبالله, بسم, الموفق, عضو, سلام, نسأل, __غرد,
# Nearest to تناول: أخذ, استخدام, استعمال, استهلاك, شرب, بتناول, وتناول, اختيار,
# Nearest to من: منها, منه, السبابه, فالواقع, ومن, الريسبردال, لأنزيم, البامية,
# Nearest to ،: ;, ,, !, )،, ., ؟, ..., ؛,
# Nearest to هذه: تلك, نفس, لهذه, هذا, بعض, وهذه, جميع, لهل,
# Nearest to الشهرية: الدموية, منتظمة, اثاء, تينوفوفير, القادمة, , التالية, الإنكار,
# Nearest to مع: ومع, عند, وعند, وبين, فالشاي, إستمرت, بسوء, البريتون,
# Nearest to بعد: قبل, وعند, عند, وبعد, دون, فلوريد, ولمدى, خلال,
# Nearest to على: وعلى, علي, عليها, الإيقاع, المعثكلة, عليه, ينقذ, نابض,
# Nearest to عن: بخصوص, لوفاستاتين, بسبب, عنها, HBV, حول, لتحديد, عنه,
# Nearest to ؟: ؟!, ؟؟, !, ،, ...., ., توفو, ,,
# Nearest to إلى: الى, والفوليك, إلي, الي, لمشكلة, إليها, المتضيق, D9,
# Nearest to لم: ولم, عندما, سوف, لا, لن, كنت, فلم, والماكولات,
# Average loss at step  252000 :  3.669636738240719
# Average loss at step  254000 :  3.709787927389145
# Average loss at step  256000 :  3.9665772935152055
# Average loss at step  258000 :  3.9512580995559694
# Average loss at step  260000 :  3.7254258530139923
# Nearest to علاج: دواء, لعلاج, معالجة, العلاج, تشخيص, Metoprolol, حفل, علاجها,
# Nearest to منع: لمنع, لحدوث, غامض, تأجيل, حدوث, تنظيم, للبيروكسيداز, والغلوكاغون,
# Nearest to و: او, ؟,, وكذلك, UNK, ولكن, , اللينوليك, باليبيريدون,
# Nearest to السلام: ورحمة, عضو, وبالله, بسم, الموفق, سلام, نسأل, __غرد,
# Nearest to تناول: أخذ, استعمال, استخدام, استهلاك, شرب, وتناول, بتناول, اختيار,
# Nearest to من: منها, ومن, البامية, وسيرشدك, فالواقع, منه, بالشوكلاته, الريسبردال,
# Nearest to ،: ;, ,, ., !, )،, ؛, -،, ..,
# Nearest to هذه: تلك, لهذه, نفس, بعض, وهذه, جميع, هذا, لهل,
# Nearest to الشهرية: الدموية, منتظمة, تينوفوفير, اثاء, القادمة, الدورة, التالية, ,
# Nearest to مع: ومع, عند, وعند, وبين, بسوء, البريتون, رغم, إستمرت,
# Nearest to بعد: قبل, عند, وعند, وبعد, منذ, دون, خلال, فلوريد,
# Nearest to على: علي, وعلى, الإيقاع, عليها, عليه, في, المعثكلة, نابض,
# Nearest to عن: عنها, لوفاستاتين, بخصوص, عنه, بسبب, حول, HBV, لتحديد,
# Nearest to ؟: ؟!, ؟؟, !, ., ،, ...., ,, ؟؟؟,
# Nearest to إلى: الى, والفوليك, إلي, الي, لمشكلة, المتضيق, سفرة, D9,
# Nearest to لم: ولم, عندما, سوف, لا, لن, كنت, فلم, والماكولات,
# Average loss at step  262000 :  3.575373148858547
# Average loss at step  264000 :  3.8796117027401924
# Average loss at step  266000 :  3.7830627373456953
# Average loss at step  268000 :  3.7562675861120223
# Average loss at step  270000 :  3.831079668998718
# Nearest to علاج: لعلاج, دواء, معالجة, العلاج, تشخيص, سبب, علاجها, حفل,
# Nearest to منع: لمنع, لحدوث, غامض, للبيروكسيداز, تنظيم, تأجيل, والغلوكاغون, الغرس,
# Nearest to و: او, وكذلك, ؟,, ولكن, UNK, , باليبيريدون, المفاغرة,
# Nearest to السلام: ورحمة, وبالله, بسم, عضو, الموفق, سلام, نسأل, التوفيق,
# Nearest to تناول: أخذ, استعمال, استخدام, استهلاك, شرب, وتناول, اختيار, بتناول,
# Nearest to من: منه, منها, السبابه, الريسبردال, المكونه, يقتل, لأنزيم, ومن,
# Nearest to ،: ;, ,, )،, !, ؛, ., -،, ؟,
# Nearest to هذه: تلك, لهذه, نفس, وهذه, هذا, جميع, بعض, لهل,
# Nearest to الشهرية: الدموية, منتظمة, اثاء, تينوفوفير, القادمة, الولادة, التالية, ,
# Nearest to مع: ومع, عند, وعند, وبين, البريتون, إستمرت, رغم, بسوء,
# Nearest to بعد: قبل, عند, وعند, وبعد, منذ, خلال, دون, فلوريد,
# Nearest to على: علي, وعلى, عليها, الإيقاع, في, المعثكلة, عليه, ذو,
# Nearest to عن: لوفاستاتين, بخصوص, عنها, عنه, حول, HBV, لتحديد, تثبيط,
# Nearest to ؟: ؟!, ؟؟, !, ،, ...., ,, توفو, ...,
# Nearest to إلى: الى, والفوليك, الي, إلي, المتضيق, سفرة, لمشكلة, D9,
# Nearest to لم: ولم, عندما, سوف, لا, لن, فلم, كنت, والماكولات,
# Average loss at step  272000 :  3.7942705209851266
# Average loss at step  274000 :  3.765124388039112
# Average loss at step  276000 :  3.681106493294239
# Average loss at step  278000 :  3.72625091946125
# Average loss at step  280000 :  3.745547028541565
# Nearest to علاج: لعلاج, معالجة, دواء, تشخيص, العلاج, سبب, حفل, وعلاج,
# Nearest to منع: لمنع, لحدوث, غامض, تنظيم, تأجيل, والغلوكاغون, للبيروكسيداز, ,
# Nearest to و: او, وكذلك, ؟,, UNK, ولكن, باليبيريدون, Mono, ,
# Nearest to السلام: وبالله, بسم, ورحمة, الموفق, عضو, سلام, نسأل, التوفيق,
# Nearest to تناول: أخذ, استعمال, استخدام, استهلاك, شرب, وتناول, اختيار, بتناول,
# Nearest to من: منها, منه, البامية, بالشوكلاته, ومن, روعة, فالواقع, مقارنه,
# Nearest to ،: ;, ,, !, ., )،, ؛, -،, ؟,
# Nearest to هذه: تلك, لهذه, وهذه, نفس, هذا, بعض, جميع, هذة,
# Nearest to الشهرية: الدموية, منتظمة, تينوفوفير, اثاء, القادمة, التالية, مخفض, الولادة,
# Nearest to مع: ومع, عند, وعند, وبين, إستمرت, البريتون, فالشاي, رغم,
# Nearest to بعد: قبل, عند, وعند, وبعد, أثناء, دون, فلوريد, ولمدى,
# Nearest to على: علي, وعلى, عليها, المعثكلة, الإيقاع, عليه, في, ع,
# Nearest to عن: عنها, لوفاستاتين, بخصوص, عنه, HBV, بسبب, تثبيط, حول,
# Nearest to ؟: ؟!, ؟؟, !, ...., ،, توفو, ,, ...,
# Nearest to إلى: الى, الي, والفوليك, إلي, المتضيق, D9, والمسؤولة, سفرة,
# Nearest to لم: ولم, عندما, سوف, فلم, لا, لن, كنت, والماكولات,
# Average loss at step  282000 :  3.545388330578804
# Average loss at step  284000 :  3.7570615550279616
# Average loss at step  286000 :  3.6991353204250337
# Average loss at step  288000 :  3.7813592084646226
# Average loss at step  290000 :  3.560643549144268
# Nearest to علاج: لعلاج, دواء, معالجة, العلاج, تشخيص, سبب, حفل, وعلاج,
# Nearest to منع: لمنع, لحدوث, غامض, تنظيم, تأجيل, للبيروكسيداز, والغلوكاغون, حدوث,
# Nearest to و: او, وكذلك, ؟,, باليبيريدون, ولكن, اطفالها, سليمتين, بتحقيرها,
# Nearest to السلام: وبالله, بسم, عضو, ورحمة, الموفق, سلام, نسأل, التوفيق,
# Nearest to تناول: أخذ, استعمال, استخدام, استهلاك, شرب, وتناول, اختيار, اخذ,
# Nearest to من: منها, روعة, ومن, فالواقع, منه, بالشوكلاته, السبابه, وعندى,
# Nearest to ،: ;, ,, !, )،, -،, ؛, ., ً،,
# Nearest to هذه: تلك, لهذه, نفس, هذا, هذة, وهذه, جميع, بعض,
# Nearest to الشهرية: الدموية, منتظمة, تينوفوفير, اثاء, القادمة, التالية, الولادة, ,
# Nearest to مع: ومع, عند, وعند, رغم, البريتون, وبين, إستمرت, فالشاي,
# Nearest to بعد: قبل, وعند, وبعد, عند, أثناء, منذ, دون, خلال,
# Nearest to على: وعلى, علي, عليها, الإيقاع, المعثكلة, عليه, بإرجاء, الأكيد,
# Nearest to عن: عنها, لوفاستاتين, بخصوص, عنه, HBV, بسبب, قميص, After,
# Nearest to ؟: ؟!, ؟؟, !, ...., ،, ,, توفو, .,
# Nearest to إلى: الى, الي, والفوليك, إلي, لمشكلة, سفرة, تفكيرهم, المتضيق,
# Nearest to لم: ولم, عندما, سوف, فلم, لن, لا, كنت, والماكولات,
# Average loss at step  292000 :  3.6722980422973635
# Average loss at step  294000 :  3.66156622415781
# Average loss at step  296000 :  3.717333024799824
# Average loss at step  298000 :  3.645086136698723

# %%
with open(os.path.join(LOG_DIR, 'vocabulary.tsv'), 'w') as f:
    [f.write(word + '\n') for word in reverse_dictionary.keys()]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-62dbdc7fcfc3> in <module>()
#       1 with open(os.path.join(LOG_DIR, 'vocabulary.tsv'), 'w') as f:
# ----> 2     [f.write_line(word) for word in reverse_dictionary.keys()]
#
# <ipython-input-20-62dbdc7fcfc3> in <listcomp>(.0)
#       1 with open(os.path.join(LOG_DIR, 'vocabulary.tsv'), 'w') as f:
# ----> 2     [f.write_line(word) for word in reverse_dictionary.keys()]
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'write_line'

# %%
from tensorflow.contrib.tensorboard.plugins import projector
# Use the same LOG_DIR where you stored your checkpoint.
summary_writer = tf.train.SummaryWriter(LOG_DIR)

# Format: tensorflow/contrib/tensorboard/plugins/projector/projector_config.proto
config = projector.ProjectorConfig()

# You can add multiple embeddings. Here we add only one.
embedding = config.embeddings.add()
embedding.tensor_name = embedding_var.name
# Link this tensor to its metadata file (e.g. labels).
embedding.metadata_path = os.path.join(LOG_DIR, 'vocabulary.tsv')

# Saves a configuration file that TensorBoard will read during startup.
projector.visualize_embeddings(summary_writer, config)

# %%
# Step 6: Visualize the embeddings.


# pylint: disable=missing-docstring
# Function to draw visualization of distance between embeddings.
def plot_with_labels(low_dim_embs, labels, filename):
    assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
    plt.figure(figsize=(18, 18))  # in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i, :]
        plt.scatter(x, y)
        
        # Arabic text preprocessing 
        reshaped_text = arabic_reshaper.reshape(label)
        label = get_display(reshaped_text)
        
        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')

    plt.savefig(filename)


try:
    # pylint: disable=g-import-not-at-top
    from sklearn.manifold import TSNE
    import matplotlib.pyplot as plt

    tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
    plot_only = 400
    low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
    labels = [reverse_dictionary[i] for i in xrange(plot_only)]
    plot_with_labels(low_dim_embs, labels, os.path.join('.', 'tsne.png'))

except ImportError as ex:
    print('Please install sklearn, matplotlib, and scipy to show embeddings.')
    print(ex)

# %%
pickle.dump(reverse_dictionary, open('vocabulary.pic', 'wb'))
pickle.dump(final_embeddings, open('embeddings.pic', 'wb'))
pickle.dump(dictionary, open('dictionary.pic', 'wb'))

# %%
with open('webteb.d128.txt', 'w', encoding='utf-8') as f:
    for key in reverse_dictionary.keys():
        print(reverse_dictionary[key] + ' ' + ' '.join([str(value) for value in final_embeddings[key]]), file=f)
