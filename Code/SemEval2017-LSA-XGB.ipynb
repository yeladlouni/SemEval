# %%
import sys
import pandas as pd
import numpy as np
import math
from scipy.spatial.distance import cosine
import xml.etree.ElementTree as ET
import pickle
import re

from nltk.corpus import stopwords

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer, HashingVectorizer
from sklearn.pipeline import Pipeline
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import Normalizer
from sklearn.model_selection import StratifiedShuffleSplit

from sklearn.ensemble import RandomForestClassifier

import xgboost as xgb

# %%
sys.path.insert(0, '../EVAL/scorer_v2.3/MAP_scripts/')
from ev import evaluate

# %%
def readXML(path):
    """
    Read XML file into a dictionary
    """
    tree = ET.parse(path)
    root = tree.getroot()
    
    dataset = pd.DataFrame(columns=['QID', 'QAID'], dtype=int)
    
    for Question in root:
        QID = int(Question.get('QID'))
        Qtext = Question.find('Qtext').text
        
        for QApair in Question.iter('QApair'): 
            QAID = int(QApair.get('QAID'))
            QArel = QApair.get('QArel')
            QAconf = QApair.get('QAconf')
            QAquestion = QApair.find('QAquestion').text
            QAanswer = QApair.find('QAanswer').text
            QAoverlap = ' '.join([w for w in wordpunct_tokenize(Qtext) if w in wordpunct_tokenize(QAquestion)])
            
            dataset = dataset.append({'QID': QID,
                                    'QAID': QAID,
                                    'Qtext': Qtext,
                                    'QAquestion': QAquestion,
                                    'QAanswer': QAanswer,
                                    'QArel': 0 if QArel == 'I' else 1,
                                    'QAconf': QAconf,
                                    'QAoverlao': QAoverlap}, ignore_index=True)

            
    dataset.set_index(['QID', 'QAID'], inplace=True)
    return dataset

# %%
test_dataset = readXML('../TEST/2017/SemEval2017-Task3-CQA-MD-test.xml')
train_dataset = readXML('../TRAIN/SemEval2016-Task3-CQA-MD-train.xml')

# %%
train_dataset = train_dataset.sort_index(level=0, ascending=[False, True])
train_dataset = train_dataset.reset_index().drop_duplicates().set_index(['QID', 'QAID'])

test_dataset = test_dataset.sort_index(level=0, ascending=[False, True])
test_dataset = test_dataset.reset_index().drop_duplicates().set_index(['QID', 'QAID'])

# %%
from nltk import wordpunct_tokenize
from nltk.stem import ISRIStemmer

class StemTokenizer(object):
    def __init__(self):
        self.wnl = ISRIStemmer()
    def __call__(self, doc):
         return [self.wnl.stem(t) for t in wordpunct_tokenize(doc)]

# %%
lsa = Pipeline([('tfidf', TfidfVectorizer())])

# %%
lsa.fit(list(set(train_dataset['QAoverlao'].append(test_dataset['QAoverlao']))))
train_overlap = lsa.transform(train_dataset['QAoverlao'])
train_labels = train_dataset['QArel']

# %%
train_overlap.shape, train_labels.shape
# Out:
# ((30411, 4388), (30411,))

# %%
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=0)
for train_index, test_index in sss.split(train_overlap, train_labels):
    X_train, y_train = train_overlap[train_index], train_labels[train_index]
    X_test, y_test = train_overlap[test_index], train_labels[test_index]

# %%
clf = xgb.XGBClassifier(n_estimators=1000)
clf.fit(X_train, y_train, eval_set=[(X_test, y_test)], eval_metric='error')
# Out:
# [0]	validation_0-error:0.397337
# [1]	validation_0-error:0.39635
# [2]	validation_0-error:0.396679
# [3]	validation_0-error:0.397008
# [4]	validation_0-error:0.396515
# [5]	validation_0-error:0.396844
# [6]	validation_0-error:0.396515
# [7]	validation_0-error:0.396186
# [8]	validation_0-error:0.396844
# [9]	validation_0-error:0.397008
# [10]	validation_0-error:0.39635
# [11]	validation_0-error:0.396022
# [12]	validation_0-error:0.396022
# [13]	validation_0-error:0.396186
# [14]	validation_0-error:0.396186
# [15]	validation_0-error:0.396186
# [16]	validation_0-error:0.396022
# [17]	validation_0-error:0.395693
# [18]	validation_0-error:0.395364
# [19]	validation_0-error:0.395364
# [20]	validation_0-error:0.3952
# [21]	validation_0-error:0.3952
# [22]	validation_0-error:0.395529
# [23]	validation_0-error:0.395364
# [24]	validation_0-error:0.395364
# [25]	validation_0-error:0.395364
# [26]	validation_0-error:0.395364
# [27]	validation_0-error:0.396186
# [28]	validation_0-error:0.39635
# [29]	validation_0-error:0.39635
# [30]	validation_0-error:0.39635
# [31]	validation_0-error:0.396186
# [32]	validation_0-error:0.39635
# [33]	validation_0-error:0.39635
# [34]	validation_0-error:0.396022
# [35]	validation_0-error:0.396022
# [36]	validation_0-error:0.396022
# [37]	validation_0-error:0.396022
# [38]	validation_0-error:0.396022
# [39]	validation_0-error:0.394707
# [40]	validation_0-error:0.394707
# [41]	validation_0-error:0.394707
# [42]	validation_0-error:0.394213
# [43]	validation_0-error:0.394542
# [44]	validation_0-error:0.394542
# [45]	validation_0-error:0.394542
# [46]	validation_0-error:0.394707
# [47]	validation_0-error:0.394707
# [48]	validation_0-error:0.394707
# [49]	validation_0-error:0.394213
# [50]	validation_0-error:0.394213
# [51]	validation_0-error:0.393391
# [52]	validation_0-error:0.393556
# [53]	validation_0-error:0.393556
# [54]	validation_0-error:0.393556
# [55]	validation_0-error:0.393556
# [56]	validation_0-error:0.393556
# [57]	validation_0-error:0.393556
# [58]	validation_0-error:0.393227
# [59]	validation_0-error:0.392734
# [60]	validation_0-error:0.392734
# [61]	validation_0-error:0.392734
# [62]	validation_0-error:0.392734
# [63]	validation_0-error:0.392734
# [64]	validation_0-error:0.392734
# [65]	validation_0-error:0.392569
# [66]	validation_0-error:0.392569
# [67]	validation_0-error:0.392734
# [68]	validation_0-error:0.392405
# [69]	validation_0-error:0.392405
# [70]	validation_0-error:0.392405
# [71]	validation_0-error:0.392405
# [72]	validation_0-error:0.392405
# [73]	validation_0-error:0.392569
# [74]	validation_0-error:0.392569
# [75]	validation_0-error:0.392569
# [76]	validation_0-error:0.392569
# [77]	validation_0-error:0.392569
# [78]	validation_0-error:0.392569
# [79]	validation_0-error:0.392405
# [80]	validation_0-error:0.392405
# [81]	validation_0-error:0.392734
# [82]	validation_0-error:0.392734
# [83]	validation_0-error:0.392734
# [84]	validation_0-error:0.392898
# [85]	validation_0-error:0.392898
# [86]	validation_0-error:0.392898
# [87]	validation_0-error:0.392898
# [88]	validation_0-error:0.392898
# [89]	validation_0-error:0.392898
# [90]	validation_0-error:0.392898
# [91]	validation_0-error:0.393227
# [92]	validation_0-error:0.393227
# [93]	validation_0-error:0.392898
# [94]	validation_0-error:0.392405
# [95]	validation_0-error:0.392405
# [96]	validation_0-error:0.392569
# [97]	validation_0-error:0.392569
# [98]	validation_0-error:0.392734
# [99]	validation_0-error:0.392569
# [100]	validation_0-error:0.392569
# [101]	validation_0-error:0.392734
# [102]	validation_0-error:0.392734
# [103]	validation_0-error:0.392734
# [104]	validation_0-error:0.392898
# [105]	validation_0-error:0.392734
# [106]	validation_0-error:0.392734
# [107]	validation_0-error:0.392734
# [108]	validation_0-error:0.392569
# [109]	validation_0-error:0.392569
# [110]	validation_0-error:0.392569
# [111]	validation_0-error:0.392569
# [112]	validation_0-error:0.392569
# [113]	validation_0-error:0.392405
# [114]	validation_0-error:0.392734
# [115]	validation_0-error:0.392734
# [116]	validation_0-error:0.392734
# [117]	validation_0-error:0.392898
# [118]	validation_0-error:0.393063
# [119]	validation_0-error:0.393556
# [120]	validation_0-error:0.393556
# [121]	validation_0-error:0.393556
# [122]	validation_0-error:0.39372
# [123]	validation_0-error:0.39372
# [124]	validation_0-error:0.393556
# [125]	validation_0-error:0.39372
# [126]	validation_0-error:0.39372
# [127]	validation_0-error:0.39372
# [128]	validation_0-error:0.393556
# [129]	validation_0-error:0.393391
# [130]	validation_0-error:0.392898
# [131]	validation_0-error:0.393063
# [132]	validation_0-error:0.392569
# [133]	validation_0-error:0.392569
# [134]	validation_0-error:0.393227
# [135]	validation_0-error:0.392898
# [136]	validation_0-error:0.392734
# [137]	validation_0-error:0.392405
# [138]	validation_0-error:0.392569
# [139]	validation_0-error:0.392569
# [140]	validation_0-error:0.392569
# [141]	validation_0-error:0.392569
# [142]	validation_0-error:0.392569
# [143]	validation_0-error:0.392734
# [144]	validation_0-error:0.392076
# [145]	validation_0-error:0.392076
# [146]	validation_0-error:0.392076
# [147]	validation_0-error:0.392241
# [148]	validation_0-error:0.392241
# [149]	validation_0-error:0.392405
# [150]	validation_0-error:0.392405
# [151]	validation_0-error:0.392569
# [152]	validation_0-error:0.392569
# [153]	validation_0-error:0.392405
# [154]	validation_0-error:0.392405
# [155]	validation_0-error:0.392076
# [156]	validation_0-error:0.391912
# [157]	validation_0-error:0.391912
# [158]	validation_0-error:0.391912
# [159]	validation_0-error:0.391912
# [160]	validation_0-error:0.392241
# [161]	validation_0-error:0.392241
# [162]	validation_0-error:0.392076
# [163]	validation_0-error:0.392241
# [164]	validation_0-error:0.392241
# [165]	validation_0-error:0.392241
# [166]	validation_0-error:0.392241
# [167]	validation_0-error:0.392241
# [168]	validation_0-error:0.392569
# [169]	validation_0-error:0.392569
# [170]	validation_0-error:0.392569
# [171]	validation_0-error:0.389775
# [172]	validation_0-error:0.389939
# [173]	validation_0-error:0.389446
# [174]	validation_0-error:0.389282
# [175]	validation_0-error:0.389117
# [176]	validation_0-error:0.388788
# [177]	validation_0-error:0.388788
# [178]	validation_0-error:0.388788
# [179]	validation_0-error:0.388953
# [180]	validation_0-error:0.388953
# [181]	validation_0-error:0.389117
# [182]	validation_0-error:0.389117
# [183]	validation_0-error:0.388953
# [184]	validation_0-error:0.389117
# [185]	validation_0-error:0.389117
# [186]	validation_0-error:0.388624
# [187]	validation_0-error:0.38846
# [188]	validation_0-error:0.38846
# [189]	validation_0-error:0.388295
# [190]	validation_0-error:0.388131
# [191]	validation_0-error:0.388131
# [192]	validation_0-error:0.387966
# [193]	validation_0-error:0.387966
# [194]	validation_0-error:0.387638
# [195]	validation_0-error:0.387145
# [196]	validation_0-error:0.387145
# [197]	validation_0-error:0.38698
# [198]	validation_0-error:0.386816
# [199]	validation_0-error:0.386651
# [200]	validation_0-error:0.386651
# [201]	validation_0-error:0.386816
# [202]	validation_0-error:0.386816
# [203]	validation_0-error:0.386816
# [204]	validation_0-error:0.386816
# [205]	validation_0-error:0.386651
# [206]	validation_0-error:0.386487
# [207]	validation_0-error:0.386487
# [208]	validation_0-error:0.386487
# [209]	validation_0-error:0.386487
# [210]	validation_0-error:0.386487
# [211]	validation_0-error:0.386487
# [212]	validation_0-error:0.386487
# [213]	validation_0-error:0.386487
# [214]	validation_0-error:0.386487
# [215]	validation_0-error:0.386651
# [216]	validation_0-error:0.386487
# [217]	validation_0-error:0.386487
# [218]	validation_0-error:0.386487
# [219]	validation_0-error:0.386323
# [220]	validation_0-error:0.386323
# [221]	validation_0-error:0.38698
# [222]	validation_0-error:0.386816
# [223]	validation_0-error:0.38698
# [224]	validation_0-error:0.38698
# [225]	validation_0-error:0.387145
# [226]	validation_0-error:0.38698
# [227]	validation_0-error:0.386816
# [228]	validation_0-error:0.386816
# [229]	validation_0-error:0.38698
# [230]	validation_0-error:0.38698
# [231]	validation_0-error:0.386816
# [232]	validation_0-error:0.386487
# [233]	validation_0-error:0.386323
# [234]	validation_0-error:0.386323
# [235]	validation_0-error:0.386323
# [236]	validation_0-error:0.386323
# [237]	validation_0-error:0.386323
# [238]	validation_0-error:0.385994
# [239]	validation_0-error:0.385994
# [240]	validation_0-error:0.386158
# [241]	validation_0-error:0.385829
# [242]	validation_0-error:0.385829
# [243]	validation_0-error:0.385665
# [244]	validation_0-error:0.385829
# [245]	validation_0-error:0.385665
# [246]	validation_0-error:0.385336
# [247]	validation_0-error:0.385994
# [248]	validation_0-error:0.385665
# [249]	validation_0-error:0.385665
# [250]	validation_0-error:0.385665
# [251]	validation_0-error:0.385665
# [252]	validation_0-error:0.385501
# [253]	validation_0-error:0.385665
# [254]	validation_0-error:0.385007
# [255]	validation_0-error:0.385172
# [256]	validation_0-error:0.384843
# [257]	validation_0-error:0.385007
# [258]	validation_0-error:0.385007
# [259]	validation_0-error:0.385007
# [260]	validation_0-error:0.385007
# [261]	validation_0-error:0.385007
# [262]	validation_0-error:0.385501
# [263]	validation_0-error:0.385501
# [264]	validation_0-error:0.385336
# [265]	validation_0-error:0.385172
# [266]	validation_0-error:0.385007
# [267]	validation_0-error:0.385007
# [268]	validation_0-error:0.385007
# [269]	validation_0-error:0.385007
# [270]	validation_0-error:0.385336
# [271]	validation_0-error:0.385336
# [272]	validation_0-error:0.385336
# [273]	validation_0-error:0.385336
# [274]	validation_0-error:0.385336
# [275]	validation_0-error:0.385336
# [276]	validation_0-error:0.385501
# [277]	validation_0-error:0.385829
# [278]	validation_0-error:0.385829
# [279]	validation_0-error:0.385829
# [280]	validation_0-error:0.385829
# [281]	validation_0-error:0.385665
# [282]	validation_0-error:0.385501
# [283]	validation_0-error:0.385336
# [284]	validation_0-error:0.385665
# [285]	validation_0-error:0.385665
# [286]	validation_0-error:0.385665
# [287]	validation_0-error:0.385665
# [288]	validation_0-error:0.385665
# [289]	validation_0-error:0.385665
# [290]	validation_0-error:0.385665
# [291]	validation_0-error:0.385501
# [292]	validation_0-error:0.385501
# [293]	validation_0-error:0.385501
# [294]	validation_0-error:0.385501
# [295]	validation_0-error:0.385665
# [296]	validation_0-error:0.385665
# [297]	validation_0-error:0.385829
# [298]	validation_0-error:0.385829
# [299]	validation_0-error:0.385665
# [300]	validation_0-error:0.385665
# [301]	validation_0-error:0.385665
# [302]	validation_0-error:0.385665
# [303]	validation_0-error:0.385665
# [304]	validation_0-error:0.385501
# [305]	validation_0-error:0.385501
# [306]	validation_0-error:0.385501
# [307]	validation_0-error:0.385501
# [308]	validation_0-error:0.385501
# [309]	validation_0-error:0.385665
# [310]	validation_0-error:0.385665
# [311]	validation_0-error:0.385501
# [312]	validation_0-error:0.385501
# [313]	validation_0-error:0.385501
# [314]	validation_0-error:0.385501
# [315]	validation_0-error:0.385665
# [316]	validation_0-error:0.385665
# [317]	validation_0-error:0.385829
# [318]	validation_0-error:0.385829
# [319]	validation_0-error:0.385994
# [320]	validation_0-error:0.386487
# [321]	validation_0-error:0.386487
# [322]	validation_0-error:0.386487
# [323]	validation_0-error:0.386487
# [324]	validation_0-error:0.386487
# [325]	validation_0-error:0.386487
# [326]	validation_0-error:0.386487
# [327]	validation_0-error:0.386487
# [328]	validation_0-error:0.386487
# [329]	validation_0-error:0.386816
# [330]	validation_0-error:0.38698
# [331]	validation_0-error:0.38698
# [332]	validation_0-error:0.386816
# [333]	validation_0-error:0.38698
# [334]	validation_0-error:0.38698
# [335]	validation_0-error:0.38698
# [336]	validation_0-error:0.38698
# [337]	validation_0-error:0.38698
# [338]	validation_0-error:0.386816
# [339]	validation_0-error:0.386816
# [340]	validation_0-error:0.386816
# [341]	validation_0-error:0.386651
# [342]	validation_0-error:0.386487
# [343]	validation_0-error:0.386816
# [344]	validation_0-error:0.386816
# [345]	validation_0-error:0.386651
# [346]	validation_0-error:0.386651
# [347]	validation_0-error:0.38698
# [348]	validation_0-error:0.387309
# [349]	validation_0-error:0.387145
# [350]	validation_0-error:0.38698
# [351]	validation_0-error:0.386323
# [352]	validation_0-error:0.386323
# [353]	validation_0-error:0.386323
# [354]	validation_0-error:0.386487
# [355]	validation_0-error:0.385994
# [356]	validation_0-error:0.385665
# [357]	validation_0-error:0.385665
# [358]	validation_0-error:0.385501
# [359]	validation_0-error:0.385501
# [360]	validation_0-error:0.385501
# [361]	validation_0-error:0.385501
# [362]	validation_0-error:0.385501
# [363]	validation_0-error:0.385007
# [364]	validation_0-error:0.385007
# [365]	validation_0-error:0.385007
# [366]	validation_0-error:0.385007
# [367]	validation_0-error:0.385007
# [368]	validation_0-error:0.385007
# [369]	validation_0-error:0.385007
# [370]	validation_0-error:0.385336
# [371]	validation_0-error:0.385501
# [372]	validation_0-error:0.385501
# [373]	validation_0-error:0.385501
# [374]	validation_0-error:0.385665
# [375]	validation_0-error:0.385665
# [376]	validation_0-error:0.385665
# [377]	validation_0-error:0.385829
# [378]	validation_0-error:0.385172
# [379]	validation_0-error:0.385172
# [380]	validation_0-error:0.385007
# [381]	validation_0-error:0.385007
# [382]	validation_0-error:0.385007
# [383]	validation_0-error:0.385007
# [384]	validation_0-error:0.385007
# [385]	validation_0-error:0.384843
# [386]	validation_0-error:0.385007
# [387]	validation_0-error:0.385007
# [388]	validation_0-error:0.385007
# [389]	validation_0-error:0.385336
# [390]	validation_0-error:0.385501
# [391]	validation_0-error:0.385501
# [392]	validation_0-error:0.385501
# [393]	validation_0-error:0.385501
# [394]	validation_0-error:0.385501
# [395]	validation_0-error:0.385501
# [396]	validation_0-error:0.385665
# [397]	validation_0-error:0.385665
# [398]	validation_0-error:0.385665
# [399]	validation_0-error:0.385665
# [400]	validation_0-error:0.385501
# [401]	validation_0-error:0.385501
# [402]	validation_0-error:0.385501
# [403]	validation_0-error:0.385829
# [404]	validation_0-error:0.385829
# [405]	validation_0-error:0.385829
# [406]	validation_0-error:0.385829
# [407]	validation_0-error:0.385829
# [408]	validation_0-error:0.385994
# [409]	validation_0-error:0.385172
# [410]	validation_0-error:0.385172
# [411]	validation_0-error:0.385172
# [412]	validation_0-error:0.385007
# [413]	validation_0-error:0.385007
# [414]	validation_0-error:0.385007
# [415]	validation_0-error:0.385994
# [416]	validation_0-error:0.385007
# [417]	validation_0-error:0.385007
# [418]	validation_0-error:0.385007
# [419]	validation_0-error:0.384843
# [420]	validation_0-error:0.384679
# [421]	validation_0-error:0.384679
# [422]	validation_0-error:0.384679
# [423]	validation_0-error:0.384679
# [424]	validation_0-error:0.384514
# [425]	validation_0-error:0.384514
# [426]	validation_0-error:0.384679
# [427]	validation_0-error:0.384679
# [428]	validation_0-error:0.384679
# [429]	validation_0-error:0.384679
# [430]	validation_0-error:0.384679
# [431]	validation_0-error:0.384679
# [432]	validation_0-error:0.384679
# [433]	validation_0-error:0.384679
# [434]	validation_0-error:0.384679
# [435]	validation_0-error:0.384679
# [436]	validation_0-error:0.384679
# [437]	validation_0-error:0.384185
# [438]	validation_0-error:0.384185
# [439]	validation_0-error:0.384185
# [440]	validation_0-error:0.38435
# [441]	validation_0-error:0.38435
# [442]	validation_0-error:0.38435
# [443]	validation_0-error:0.384185
# [444]	validation_0-error:0.384021
# [445]	validation_0-error:0.383692
# [446]	validation_0-error:0.384021
# [447]	validation_0-error:0.384021
# [448]	validation_0-error:0.383857
# [449]	validation_0-error:0.383857
# [450]	validation_0-error:0.384021
# [451]	validation_0-error:0.383857
# [452]	validation_0-error:0.384021
# [453]	validation_0-error:0.383857
# [454]	validation_0-error:0.384185
# [455]	validation_0-error:0.384185
# [456]	validation_0-error:0.384185
# [457]	validation_0-error:0.384185
# [458]	validation_0-error:0.384185
# [459]	validation_0-error:0.384185
# [460]	validation_0-error:0.384185
# [461]	validation_0-error:0.384185
# [462]	validation_0-error:0.384185
# [463]	validation_0-error:0.384021
# [464]	validation_0-error:0.384021
# [465]	validation_0-error:0.384021
# [466]	validation_0-error:0.384021
# [467]	validation_0-error:0.384021
# [468]	validation_0-error:0.384021
# [469]	validation_0-error:0.383857
# [470]	validation_0-error:0.383857
# [471]	validation_0-error:0.383857
# [472]	validation_0-error:0.383857
# [473]	validation_0-error:0.383857
# [474]	validation_0-error:0.383692
# [475]	validation_0-error:0.383692
# [476]	validation_0-error:0.383692
# [477]	validation_0-error:0.383857
# [478]	validation_0-error:0.383857
# [479]	validation_0-error:0.383857
# [480]	validation_0-error:0.383857
# [481]	validation_0-error:0.383857
# [482]	validation_0-error:0.383857
# [483]	validation_0-error:0.383692
# [484]	validation_0-error:0.383363
# [485]	validation_0-error:0.383528
# [486]	validation_0-error:0.383528
# [487]	validation_0-error:0.383692
# [488]	validation_0-error:0.383692
# [489]	validation_0-error:0.383692
# [490]	validation_0-error:0.383692
# [491]	validation_0-error:0.383363
# [492]	validation_0-error:0.383363
# [493]	validation_0-error:0.383528
# [494]	validation_0-error:0.383363
# [495]	validation_0-error:0.38287
# [496]	validation_0-error:0.38287
# [497]	validation_0-error:0.383035
# [498]	validation_0-error:0.38287
# [499]	validation_0-error:0.382706
# [500]	validation_0-error:0.382706
# [501]	validation_0-error:0.382706
# [502]	validation_0-error:0.382706
# [503]	validation_0-error:0.382706
# [504]	validation_0-error:0.382706
# [505]	validation_0-error:0.382706
# [506]	validation_0-error:0.382706
# [507]	validation_0-error:0.382377
# [508]	validation_0-error:0.382213
# [509]	validation_0-error:0.382377
# [510]	validation_0-error:0.382377
# [511]	validation_0-error:0.382377
# [512]	validation_0-error:0.382542
# [513]	validation_0-error:0.382542
# [514]	validation_0-error:0.382542
# [515]	validation_0-error:0.382542
# [516]	validation_0-error:0.382377
# [517]	validation_0-error:0.382542
# [518]	validation_0-error:0.382542
# [519]	validation_0-error:0.382542
# [520]	validation_0-error:0.382542
# [521]	validation_0-error:0.382542
# [522]	validation_0-error:0.382542
# [523]	validation_0-error:0.382706
# [524]	validation_0-error:0.38287
# [525]	validation_0-error:0.38287
# [526]	validation_0-error:0.38287
# [527]	validation_0-error:0.38287
# [528]	validation_0-error:0.383035
# [529]	validation_0-error:0.383035
# [530]	validation_0-error:0.383035
# [531]	validation_0-error:0.38287
# [532]	validation_0-error:0.383035
# [533]	validation_0-error:0.38287
# [534]	validation_0-error:0.38287
# [535]	validation_0-error:0.38287
# [536]	validation_0-error:0.382706
# [537]	validation_0-error:0.383199
# [538]	validation_0-error:0.383363
# [539]	validation_0-error:0.383363
# [540]	validation_0-error:0.383528
# [541]	validation_0-error:0.383528
# [542]	validation_0-error:0.383692
# [543]	validation_0-error:0.383692
# [544]	validation_0-error:0.383692
# [545]	validation_0-error:0.383528
# [546]	validation_0-error:0.383528
# [547]	validation_0-error:0.383528
# [548]	validation_0-error:0.383528
# [549]	validation_0-error:0.383528
# [550]	validation_0-error:0.383528
# [551]	validation_0-error:0.383692
# [552]	validation_0-error:0.383692
# [553]	validation_0-error:0.383857
# [554]	validation_0-error:0.383692
# [555]	validation_0-error:0.383692
# [556]	validation_0-error:0.383692
# [557]	validation_0-error:0.383692
# [558]	validation_0-error:0.383692
# [559]	validation_0-error:0.383857
# [560]	validation_0-error:0.383857
# [561]	validation_0-error:0.383692
# [562]	validation_0-error:0.383857
# [563]	validation_0-error:0.383363
# [564]	validation_0-error:0.383363
# [565]	validation_0-error:0.383363
# [566]	validation_0-error:0.383363
# [567]	validation_0-error:0.383199
# [568]	validation_0-error:0.383199
# [569]	validation_0-error:0.38287
# [570]	validation_0-error:0.382706
# [571]	validation_0-error:0.382706
# [572]	validation_0-error:0.38287
# [573]	validation_0-error:0.38287
# [574]	validation_0-error:0.382706
# [575]	validation_0-error:0.382542
# [576]	validation_0-error:0.38287
# [577]	validation_0-error:0.38287
# [578]	validation_0-error:0.383199
# [579]	validation_0-error:0.383199
# [580]	validation_0-error:0.383035
# [581]	validation_0-error:0.383199
# [582]	validation_0-error:0.38287
# [583]	validation_0-error:0.382706
# [584]	validation_0-error:0.382706
# [585]	validation_0-error:0.382706
# [586]	validation_0-error:0.382706
# [587]	validation_0-error:0.382377
# [588]	validation_0-error:0.382377
# [589]	validation_0-error:0.382377
# [590]	validation_0-error:0.382377
# [591]	validation_0-error:0.382377
# [592]	validation_0-error:0.382377
# [593]	validation_0-error:0.382213
# [594]	validation_0-error:0.382213
# [595]	validation_0-error:0.382213
# [596]	validation_0-error:0.382377
# [597]	validation_0-error:0.382377
# [598]	validation_0-error:0.381884
# [599]	validation_0-error:0.382213
# [600]	validation_0-error:0.382213
# [601]	validation_0-error:0.382213
# [602]	validation_0-error:0.382213
# [603]	validation_0-error:0.382213
# [604]	validation_0-error:0.382213
# [605]	validation_0-error:0.382213
# [606]	validation_0-error:0.382213
# [607]	validation_0-error:0.382706
# [608]	validation_0-error:0.382706
# [609]	validation_0-error:0.382706
# [610]	validation_0-error:0.382706
# [611]	validation_0-error:0.382706
# [612]	validation_0-error:0.38287
# [613]	validation_0-error:0.38287
# [614]	validation_0-error:0.38287
# [615]	validation_0-error:0.382706
# [616]	validation_0-error:0.382706
# [617]	validation_0-error:0.382706
# [618]	validation_0-error:0.38287
# [619]	validation_0-error:0.382706
# [620]	validation_0-error:0.382706
# [621]	validation_0-error:0.382706
# [622]	validation_0-error:0.382706
# [623]	validation_0-error:0.382706
# [624]	validation_0-error:0.382706
# [625]	validation_0-error:0.382706
# [626]	validation_0-error:0.382706
# [627]	validation_0-error:0.382542
# [628]	validation_0-error:0.382542
# [629]	validation_0-error:0.382542
# [630]	validation_0-error:0.382542
# [631]	validation_0-error:0.382706
# [632]	validation_0-error:0.382706
# [633]	validation_0-error:0.382706
# [634]	validation_0-error:0.38287
# [635]	validation_0-error:0.383035
# [636]	validation_0-error:0.383035
# [637]	validation_0-error:0.383199
# [638]	validation_0-error:0.383363
# [639]	validation_0-error:0.383363
# [640]	validation_0-error:0.383363
# [641]	validation_0-error:0.383692
# [642]	validation_0-error:0.383692
# [643]	validation_0-error:0.383692
# [644]	validation_0-error:0.383528
# [645]	validation_0-error:0.382706
# [646]	validation_0-error:0.382706
# [647]	validation_0-error:0.382706
# [648]	validation_0-error:0.382377
# [649]	validation_0-error:0.382377
# [650]	validation_0-error:0.382377
# [651]	validation_0-error:0.382377
# [652]	validation_0-error:0.382377
# [653]	validation_0-error:0.382377
# [654]	validation_0-error:0.382048
# [655]	validation_0-error:0.381884
# [656]	validation_0-error:0.381555
# [657]	validation_0-error:0.381555
# [658]	validation_0-error:0.381391
# [659]	validation_0-error:0.381391
# [660]	validation_0-error:0.381391
# [661]	validation_0-error:0.381391
# [662]	validation_0-error:0.381391
# [663]	validation_0-error:0.381391
# [664]	validation_0-error:0.38172
# [665]	validation_0-error:0.381884
# [666]	validation_0-error:0.381884
# [667]	validation_0-error:0.381884
# [668]	validation_0-error:0.38172
# [669]	validation_0-error:0.38172
# [670]	validation_0-error:0.382048
# [671]	validation_0-error:0.382048
# [672]	validation_0-error:0.381884
# [673]	validation_0-error:0.38172
# [674]	validation_0-error:0.38172
# [675]	validation_0-error:0.38172
# [676]	validation_0-error:0.381555
# [677]	validation_0-error:0.381391
# [678]	validation_0-error:0.381555
# [679]	validation_0-error:0.381555
# [680]	validation_0-error:0.381555
# [681]	validation_0-error:0.381555
# [682]	validation_0-error:0.381226
# [683]	validation_0-error:0.381391
# [684]	validation_0-error:0.381226
# [685]	validation_0-error:0.381226
# [686]	validation_0-error:0.381226
# [687]	validation_0-error:0.381226
# [688]	validation_0-error:0.380569
# [689]	validation_0-error:0.380569
# [690]	validation_0-error:0.380569
# [691]	validation_0-error:0.379254
# [692]	validation_0-error:0.379418
# [693]	validation_0-error:0.379582
# [694]	validation_0-error:0.379254
# [695]	validation_0-error:0.379418
# [696]	validation_0-error:0.379254
# [697]	validation_0-error:0.379254
# [698]	validation_0-error:0.379418
# [699]	validation_0-error:0.379418
# [700]	validation_0-error:0.379254
# [701]	validation_0-error:0.379418
# [702]	validation_0-error:0.379418
# [703]	validation_0-error:0.379418
# [704]	validation_0-error:0.379418
# [705]	validation_0-error:0.379418
# [706]	validation_0-error:0.379582
# [707]	validation_0-error:0.378596
# [708]	validation_0-error:0.379254
# [709]	validation_0-error:0.378267
# [710]	validation_0-error:0.379254
# [711]	validation_0-error:0.378267
# [712]	validation_0-error:0.377939
# [713]	validation_0-error:0.377939
# [714]	validation_0-error:0.377939
# [715]	validation_0-error:0.377939
# [716]	validation_0-error:0.377939
# [717]	validation_0-error:0.377939
# [718]	validation_0-error:0.377774
# [719]	validation_0-error:0.377774
# [720]	validation_0-error:0.377774
# [721]	validation_0-error:0.377939
# [722]	validation_0-error:0.377939
# [723]	validation_0-error:0.377939
# [724]	validation_0-error:0.377939
# [725]	validation_0-error:0.377939
# [726]	validation_0-error:0.378103
# [727]	validation_0-error:0.378103
# [728]	validation_0-error:0.379254
# [729]	validation_0-error:0.379089
# [730]	validation_0-error:0.379089
# [731]	validation_0-error:0.379089
# [732]	validation_0-error:0.378103
# [733]	validation_0-error:0.378103
# [734]	validation_0-error:0.378103
# [735]	validation_0-error:0.377939
# [736]	validation_0-error:0.377939
# [737]	validation_0-error:0.377939
# [738]	validation_0-error:0.377939
# [739]	validation_0-error:0.378103
# [740]	validation_0-error:0.378267
# [741]	validation_0-error:0.378267
# [742]	validation_0-error:0.378267
# [743]	validation_0-error:0.378267
# [744]	validation_0-error:0.378267
# [745]	validation_0-error:0.378267
# [746]	validation_0-error:0.378103
# [747]	validation_0-error:0.378103
# [748]	validation_0-error:0.378103
# [749]	validation_0-error:0.378267
# [750]	validation_0-error:0.378267
# [751]	validation_0-error:0.378267
# [752]	validation_0-error:0.378267
# [753]	validation_0-error:0.378267
# [754]	validation_0-error:0.378267
# [755]	validation_0-error:0.378103
# [756]	validation_0-error:0.378103
# [757]	validation_0-error:0.378267
# [758]	validation_0-error:0.378267
# [759]	validation_0-error:0.378267
# [760]	validation_0-error:0.378103
# [761]	validation_0-error:0.378103
# [762]	validation_0-error:0.378103
# [763]	validation_0-error:0.378103
# [764]	validation_0-error:0.377774
# [765]	validation_0-error:0.377774
# [766]	validation_0-error:0.377774
# [767]	validation_0-error:0.377774
# [768]	validation_0-error:0.377774
# [769]	validation_0-error:0.377774
# [770]	validation_0-error:0.377774
# [771]	validation_0-error:0.377774
# [772]	validation_0-error:0.377774
# [773]	validation_0-error:0.377939
# [774]	validation_0-error:0.377939
# [775]	validation_0-error:0.377939
# [776]	validation_0-error:0.377939
# [777]	validation_0-error:0.378103
# [778]	validation_0-error:0.378103
# [779]	validation_0-error:0.378103
# [780]	validation_0-error:0.378103
# [781]	validation_0-error:0.378103
# [782]	validation_0-error:0.377939
# [783]	validation_0-error:0.377939
# [784]	validation_0-error:0.377939
# [785]	validation_0-error:0.377774
# [786]	validation_0-error:0.377774
# [787]	validation_0-error:0.377774
# [788]	validation_0-error:0.377774
# [789]	validation_0-error:0.377774
# [790]	validation_0-error:0.377939
# [791]	validation_0-error:0.377774
# [792]	validation_0-error:0.377774
# [793]	validation_0-error:0.37761
# [794]	validation_0-error:0.377445
# [795]	validation_0-error:0.377445
# [796]	validation_0-error:0.377281
# [797]	validation_0-error:0.377281
# [798]	validation_0-error:0.377281
# [799]	validation_0-error:0.377117
# [800]	validation_0-error:0.377117
# [801]	validation_0-error:0.377117
# [802]	validation_0-error:0.377117
# [803]	validation_0-error:0.377117
# [804]	validation_0-error:0.377117
# [805]	validation_0-error:0.377117
# [806]	validation_0-error:0.377117
# [807]	validation_0-error:0.377117
# [808]	validation_0-error:0.377117
# [809]	validation_0-error:0.377117
# [810]	validation_0-error:0.377117
# [811]	validation_0-error:0.377117
# [812]	validation_0-error:0.377117
# [813]	validation_0-error:0.377117
# [814]	validation_0-error:0.377117
# [815]	validation_0-error:0.377117
# [816]	validation_0-error:0.377117
# [817]	validation_0-error:0.377117
# [818]	validation_0-error:0.377117
# [819]	validation_0-error:0.376952
# [820]	validation_0-error:0.377117
# [821]	validation_0-error:0.377117
# [822]	validation_0-error:0.377117
# [823]	validation_0-error:0.377117
# [824]	validation_0-error:0.376952
# [825]	validation_0-error:0.376952
# [826]	validation_0-error:0.376623
# [827]	validation_0-error:0.376788
# [828]	validation_0-error:0.376623
# [829]	validation_0-error:0.376623
# [830]	validation_0-error:0.376788
# [831]	validation_0-error:0.376623
# [832]	validation_0-error:0.376623
# [833]	validation_0-error:0.376788
# [834]	validation_0-error:0.376952
# [835]	validation_0-error:0.376952
# [836]	validation_0-error:0.377117
# [837]	validation_0-error:0.376788
# [838]	validation_0-error:0.376788
# [839]	validation_0-error:0.376788
# [840]	validation_0-error:0.376788
# [841]	validation_0-error:0.376952
# [842]	validation_0-error:0.37761
# [843]	validation_0-error:0.377445
# [844]	validation_0-error:0.377445
# [845]	validation_0-error:0.377281
# [846]	validation_0-error:0.377117
# [847]	validation_0-error:0.377117
# [848]	validation_0-error:0.377117
# [849]	validation_0-error:0.377117
# [850]	validation_0-error:0.377117
# [851]	validation_0-error:0.377117
# [852]	validation_0-error:0.377117
# [853]	validation_0-error:0.376952
# [854]	validation_0-error:0.376952
# [855]	validation_0-error:0.377117
# [856]	validation_0-error:0.377117
# [857]	validation_0-error:0.377117
# [858]	validation_0-error:0.377117
# [859]	validation_0-error:0.377117
# [860]	validation_0-error:0.377117
# [861]	validation_0-error:0.377117
# [862]	validation_0-error:0.376952
# [863]	validation_0-error:0.376952
# [864]	validation_0-error:0.376952
# [865]	validation_0-error:0.376952
# [866]	validation_0-error:0.376952
# [867]	validation_0-error:0.376952
# [868]	validation_0-error:0.37613
# [869]	validation_0-error:0.37613
# [870]	validation_0-error:0.37613
# [871]	validation_0-error:0.376295
# [872]	validation_0-error:0.376295
# [873]	validation_0-error:0.376459
# [874]	validation_0-error:0.376623
# [875]	validation_0-error:0.376623
# [876]	validation_0-error:0.376623
# [877]	validation_0-error:0.376623
# [878]	validation_0-error:0.376788
# [879]	validation_0-error:0.376788
# [880]	validation_0-error:0.376788
# [881]	validation_0-error:0.377281
# [882]	validation_0-error:0.377281
# [883]	validation_0-error:0.377117
# [884]	validation_0-error:0.376952
# [885]	validation_0-error:0.376623
# [886]	validation_0-error:0.376623
# [887]	validation_0-error:0.376459
# [888]	validation_0-error:0.376295
# [889]	validation_0-error:0.376295
# [890]	validation_0-error:0.376295
# [891]	validation_0-error:0.376295
# [892]	validation_0-error:0.376295
# [893]	validation_0-error:0.376295
# [894]	validation_0-error:0.376295
# [895]	validation_0-error:0.376295
# [896]	validation_0-error:0.376295
# [897]	validation_0-error:0.376295
# [898]	validation_0-error:0.376295
# [899]	validation_0-error:0.376295
# [900]	validation_0-error:0.376295
# [901]	validation_0-error:0.376459
# [902]	validation_0-error:0.376459
# [903]	validation_0-error:0.376459
# [904]	validation_0-error:0.376459
# [905]	validation_0-error:0.376459
# [906]	validation_0-error:0.376295
# [907]	validation_0-error:0.376459
# [908]	validation_0-error:0.376623
# [909]	validation_0-error:0.376459
# [910]	validation_0-error:0.376295
# [911]	validation_0-error:0.376295
# [912]	validation_0-error:0.376295
# [913]	validation_0-error:0.376295
# [914]	validation_0-error:0.37613
# [915]	validation_0-error:0.375801
# [916]	validation_0-error:0.375801
# [917]	validation_0-error:0.375801
# [918]	validation_0-error:0.375966
# [919]	validation_0-error:0.375966
# [920]	validation_0-error:0.375966
# [921]	validation_0-error:0.375966
# [922]	validation_0-error:0.375966
# [923]	validation_0-error:0.375966
# [924]	validation_0-error:0.375966
# [925]	validation_0-error:0.375966
# [926]	validation_0-error:0.375966
# [927]	validation_0-error:0.375966
# [928]	validation_0-error:0.375966
# [929]	validation_0-error:0.375966
# [930]	validation_0-error:0.375801
# [931]	validation_0-error:0.375966
# [932]	validation_0-error:0.375801
# [933]	validation_0-error:0.375801
# [934]	validation_0-error:0.375801
# [935]	validation_0-error:0.37613
# [936]	validation_0-error:0.37613
# [937]	validation_0-error:0.37613
# [938]	validation_0-error:0.375966
# [939]	validation_0-error:0.375966
# [940]	validation_0-error:0.375801
# [941]	validation_0-error:0.375801
# [942]	validation_0-error:0.375966
# [943]	validation_0-error:0.37613
# [944]	validation_0-error:0.37613
# [945]	validation_0-error:0.37613
# [946]	validation_0-error:0.375966
# [947]	validation_0-error:0.375966
# [948]	validation_0-error:0.376295
# [949]	validation_0-error:0.376295
# [950]	validation_0-error:0.376295
# [951]	validation_0-error:0.376459
# [952]	validation_0-error:0.376295
# [953]	validation_0-error:0.376295
# [954]	validation_0-error:0.376295
# [955]	validation_0-error:0.376459
# [956]	validation_0-error:0.376459
# [957]	validation_0-error:0.376459
# [958]	validation_0-error:0.376295
# [959]	validation_0-error:0.376295
# [960]	validation_0-error:0.37613
# [961]	validation_0-error:0.37613
# [962]	validation_0-error:0.37613
# [963]	validation_0-error:0.376295
# [964]	validation_0-error:0.376295
# [965]	validation_0-error:0.376295
# [966]	validation_0-error:0.376295
# [967]	validation_0-error:0.376295
# [968]	validation_0-error:0.37613
# [969]	validation_0-error:0.376295
# [970]	validation_0-error:0.376295
# [971]	validation_0-error:0.376295
# [972]	validation_0-error:0.376295
# [973]	validation_0-error:0.37613
# [974]	validation_0-error:0.37613
# [975]	validation_0-error:0.37613
# [976]	validation_0-error:0.37613
# [977]	validation_0-error:0.37613
# [978]	validation_0-error:0.375966
# [979]	validation_0-error:0.375308
# [980]	validation_0-error:0.375473
# [981]	validation_0-error:0.375473
# [982]	validation_0-error:0.375637
# [983]	validation_0-error:0.375637
# [984]	validation_0-error:0.375637
# [985]	validation_0-error:0.375637
# [986]	validation_0-error:0.375637
# [987]	validation_0-error:0.375637
# [988]	validation_0-error:0.375801
# [989]	validation_0-error:0.375637
# [990]	validation_0-error:0.375637
# [991]	validation_0-error:0.375473
# [992]	validation_0-error:0.375473
# [993]	validation_0-error:0.375473
# [994]	validation_0-error:0.375473
# [995]	validation_0-error:0.374651
# [996]	validation_0-error:0.375144
# [997]	validation_0-error:0.375144
# [998]	validation_0-error:0.374651
# [999]	validation_0-error:0.374815
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=1000,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
test_overlap = lsa.transform(test_dataset['QAoverlao'])
test_labels = test_dataset['QArel']

# %%
test_overlap.shape, test_labels.shape
# Out:
# ((12581, 4388), (12581,))

# %%
clf.predict_proba(test_overlap)
# Out:
# array([[ 0.44275808,  0.55724192],
#        [ 0.44275808,  0.55724192],
#        [ 0.44275808,  0.55724192],
#        ...,
#        [ 0.45959127,  0.54040873],
#        [ 0.41049111,  0.58950889],
#        [ 0.50280893,  0.49719104]], dtype=float32)

# %%
test_dataset['score'] = [score[1] for score in clf.predict_proba(test_overlap)]

# %%
test_dataset['relevance'] = ['true' if rel == 1.0 else 'false' for rel in clf.predict(test_overlap)]

# %%
test_dataset['rank'] = 0

# %%
test_dataset.to_csv('../EVAL/SemEval2017-Task3-CQA-MD-test-lsa-mlp.xml.pred', sep='\t', header=None, columns=['QID', 'QAID', 'rank', 'score', 'relevance' ])
# Out:
# c:\python35\lib\site-packages\pandas\core\indexing.py:972: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_nested_tuple(tup)

# %%
test_dataset = test_dataset.sort_index(level=0, ascending=[False, True])
test_dataset = test_dataset.reset_index().drop_duplicates().set_index(['QID', 'QAID'])
test_dataset
# Out:
#                                                        QAanswer QAconf  \
# QID   QAID
# 69579 43523   يعود تطبل البطن أو ما يعرف بغازات البطن الى ال...   None
#       51753   قبل أن تبدأ ببرنامج المشي، يتطلب منك أن تعرف ف...   None
#       61846   التهاب الدم أو ما يعرف طبيا بتعفن الدم هو أحد ...   None
#       63972   التهاب الكلى هو أمر شائع لدى مرضى الذئبة و يحد...   None
#       117912  الأول هو اخْتِبار أَضْدادِ الحالَّةِ العُقْدِي...   None
#       229172  العصب بنقل الايعازات الحسية والحركية من الجهاز...   None
#       289894  لا ينصح باستخدام الكورتيزون بهدف زيادة الوزن ل...   None
#       684584  غالبا هذا سببه الرهاب الاجتماعي و رغم ذلك بجب ...   None
#       880238           نبدأ بعلاج دوائي اذا لم ينفع بنعمل الكي   None
# 69578 47192   ممكن ان يكون شئ طبيعي لكن للاطمئنان انصحك بمرا...   None
#       52302   نرجو عمل الفحوصات التالية لتحديد طبيعة عمل الم...   None
#       86270   انصحك باجراء فحص لنسبه هرمون الحمل بالدم. واذا...   None
#       304444                                  يجب عمل فحص الحمل   None
#       432499  يجب انتظار الدورة اذا لم تاتى فيمكن عمل تحليل ...   None
#       561870       تحدث مثل هذه الاعراض مع الدورة ولاشىء فى ذلك   None
#       696681  بعد الاحهاض او الولاده وارد ان تتاخر الدوره لا...   None
#       756956  خط واحد يعني ما في حمل انتطري ختنزل الدوره لو ...   None
#       875015  الدورة غير منتظمة ولا يمكن الحساب عليها ويجب م...   None
# 69577 22960   غازات وانتفاخ البطن اسبابه عديده من أبرزها الا...   None
#       28732   هذه الأعراض تظهر عادة في وقت واحد في حالات الق...   None
#       37830   عليك مراجعة اختصاصي الجراحة العامة لتقييم الفت...   None
#       53616   لا داعي للقلق، ولكن الخطوة الأولى تتركز على مح...   None
#       65280   الدوخة أو الدوار هما إحساس المريض بدوران الجسم...   None
#       108734  يجب فحصك من قبل طبيب لمعرفة سبب الالم ان كان ف...   None
#       131938  رغم أنك ذكرت أن فحوصات القلب سليمة لم تتطرق إل...   None
#       293946  لا بد من فحص الطبي مباشر للكشف عن العلامات الس...   None
#       836838  جرثومة المعده.... لا تسبب هذه الاعراض(امساك/صد...   None
# 69576 8978    مغاطس ماء فاتر مع البرمنغنات. أو مع البابونج.و...   None
#       56635   معظم الشقوق لا تحتاج لعلاج وقد تختفي الأعراض خ...   None
#       66564   بما انها لا تسبب الم او نزف.....فالمطلوب هو ان...   None
# ...                                                         ...    ...
# 66718 364491  الأعراض التي ذكرتها غالبا ماتكون بسبب النبضات ...   None
#       372893  الأخت الفاضلة! العكس هو الصحيح , فان الوسواس و...   None
#       720920  يجب اولا فحص ما قلت انه تحجر من قبل طبيب جراح ...   None
# 66715 42543   :لا يوجد علاج شافي للحساسية وإنما علاجات تخفف ...   None
#       54742   هذه الحبوب هي حب شباب ،أسباب ظهور حب الشباب يت...   None
#       56706   أسباب ظهور حب الشباب يتعلق بحدوث تغيرات عمرية ...   None
#       58177   هي حبوب دهنية بسبب زيادة افراز الغدد الدهنية ا...   None
#       68780   أولا يجب علاج حب الشباب وبعدها يب\أ علاج البثو...   None
#       70595   هذه الحبوب هي حب شبابأسباب ظهور حب الشباب يتعل...   None
#       218846  بالنسبة للأشخاص الذين يعانون من حب الشباب تقوم...   None
#       593669           اقراص الرواكتان بعد عمل التحاليل اللازمه   None
#       829322  استخدمي كريم يحتوي كورتيكوستيرويد ومضاد حيوي ,...   None
# 66713 24877   هو انخفاض معدل ضربات القلب إلى ما دون 60 نبضة ...   None
#       31036                     نعم تعتبر طبيعية ولا داعي للقلق   None
#       38495   لأن النِّتاج القَلْبِي يزداد مع زيادة حجم الجس...   None
#       58127   الموت مفارقة الحياة للجسم، وهو تعبير عن توقف ل...   None
#       93012   هكذا نبض إذا لم يرفقه أعراض يعتبر طبيعي خاصة ع...   None
#       182904  نعم توجد علاقة وغقاً لحدتها نقصاً أو زيادة أما...   None
#       309036      حسب العمر والجنس ومتوسطها يتراوح بين 60 ومائة   None
#       352144  بداية ان معدل نبضات القلب الطبيعي هو من 60-100...   None
#       648111  معدل ضربات القلب تختلف عند الانسان حسب العمر ح...   None
# 66711 46944   لزيادة الوزن لابد من تناول طعام اكثر مما يتم ا...   None
#       78260   يجب مراجعة طبيب لعمل فحوصات للدم لمعرفة السبب ...   None
#       115106  البروتين بحد ذاته لا يسبب ارتفاع ضغط الدم, بل ...   None
#       195574  المصادر الغذائية للجلوتامين-ل تشمل لحوم البقر ...   None
#       280600  بالنسبة لعمرك وطولك فإن وزنك المثالي تقريبا 68...   None
#       355209  في هذا السن يتناول الطفل الخضار بجميع انواعها ...   None
#       380008  لا يجب اعطائه للأطفال فهو غير مخصص لهم، يجب ال...   None
#       499827  البروتين الحيواني مهم لانه يحتوي علي الاحماض ا...   None
#       882992                                         وزنك مثالي   None
#
#                                               QAoverlao  \
# QID   QAID
# 69579 43523                                       القلب
#       51753
#       61846
#       63972
#       117912
#       229172                     عدم انتظام ضربات القلب
#       289894
#       684584                                ضربات القلب
#       880238                                      القلب
# 69578 47192                       متزوجة في تاتي يوم في
#       52302    متزوجة شهرين في جاتني علما تحليل في الدم
#       86270   متزوجة شهرين في الشهر الاول الثاني حمل في
#       304444                   متزوجة علما يوم حمل الدم
#       432499                                 متزوجة يوم
#       561870                          شهرين في يوم في ؟
#       696681             شهرين الشهر جاتني الثاني اليوم
#       756956                            شهرين جاتني حمل
#       875015        متزوجة في الشهر جاتني دورة يوم في ؟
# 69577 22960                           اعاني من وضيق مرض
#       28732                                           ؟
#       37830                                 اعاني من في
#       53616                                  من دوخة في
#       65280                                          من
#       108734                         اعاني وتعب في ما ؟
#       131938                   اعاني من دوخة وتعب في هي
#       293946                                   اعاني من
#       836838               اعاني من دوخة وتعب وضيق هي ؟
# 69576 8978                                            ؟
#       56635                                  ما هو علاج
#       66564                                  البواسير ؟
# ...                                                 ...
# 66718 364491                                      جدا ؟
#       372893                                       توتر
#       720920
# 66715 42543                           من في وجهي الخدين
#       54742                          الحبوب في وجهي على
#       56706                         اعاني من ما المناسب
#       58177       اعاني من ظهور الحبوب في وجهي الجبهة ؟
#       68780                             اعاني من على هو
#       70595                                          من
#       218846                 اعاني من الحبوب في وجهي ما
#       593669                     اعاني من ظهور وجهي على
#       829322        من ظهور الحبوب وجهي باستمرار على ما
# 66713 24877                                       القلب
#       31036                                       القلب
#       38495
#       58127
#       93012                                 ضربات القلب
#       182904                            عدد ضربات القلب
#       309036                       ما عدد ضربات القلب ؟
#       352144                                      عند ؟
#       648111                          ما القلب الطبيعية
# 66711 46944
#       78260                                       هل في
#       115106                        هل البروتينات وخاصة
#       195574                                         هل
#       280600
#       355209                              وهي هل هذه في
#       380008                             بروتين هل كمال
#       499827                                        هذه
#       882992                                         هل
#
#                                                      QAquestion  QArel  \
# QID   QAID
# 69579 43523   اعاني من سرعة نبضات القلب وضيق في التنفس وألم ...    1.0
#       51753   هل المشي الغير سريع والذي لا يحدث خفقان سريع و...    1.0
#       61846         ماهم التهاب الدم وماهي اعراضه وكيفية علاجه؟    0.0
#       63972    أثار مرض الذئبة الحمراء على الكلى والعلاج الفعال    0.0
#       117912  السلام عليكم قمت مؤخرا باجراء تحاليل aslo و cr...    0.0
#       229172  ما الاضرار الناتجة عن زيادة نشاط العصب الحائر ...    1.0
#       289894  اريد ان اعرف ما هى جرعات دواء ال dexamethasone...    0.0
#       684584  لدى زياد في ضربات القلب و رعشة بمجرد حدوث أمر ...    1.0
#       880238  جوزي عنده نبضات القلب سريعه بتوصل 145 وتضخم في...    1.0
# 69578 47192   مرحبا انا عمري 25 وغير متزوجة دورتي كانت تاتي ...    0.0
#       52302   السلام عليكم انا عندي لخبطة بالدورة الشهرية ان...    0.0
#       86270   السلام عليكم ورحمة الله انا فتاه متزوجة اجهضت ...    1.0
#       304444  انا متزوجة وجاءت الدورة لمدة نصف يوم وانقطعت ع...    0.0
#       432499  انا متزوجة جات مواعيد الدورة الشهرية ألم شديد ...    1.0
#       561870  انا متزوجه من شهرين وعمري 16 الدوره عندي منتظم...    0.0
#       696681  السلام عليكم انا متزوجه من 7اشهر وحملت مره وسق...    0.0
#       756956  انا متزوجه من شهرين جاتني الدوره بعد العرس متا...    1.0
#       875015  دكتور دورة في شهر عشرة جاتني يوم ١٢ اما ها الش...    0.0
# 69577 22960   . انا اعاني من غازات (كثرة التجشؤ) وضيق بالتنف...    0.0
#       28732   ماهى اسباب الدوخة والدوار يصحبه صداع وشعور با ...    1.0
#       37830   اعاني من ضيق في التنفس مع الم في الراس ودوخه ب...    1.0
#       53616   لماذا أحس بالتعب في بعض الأحيان و ضيق النفس و ...    1.0
#       65280   السلام عليكوم اشعر بدوار ودوخه من فتره وعدام ا...    1.0
#       108734  ما اعاني منه الم في الظهر واسفل البطن وخمول وت...    0.0
#       131938  اعاني من دوخة وآلام في الكتف واعلى الصدر جهة ا...    1.0
#       293946  انا فتاة اعاني من ضيق نفس و دوخه و مرات ينقطع ...    1.0
#       836838  اعاني من إسهال وامساك معا و دوخة. عمري 26سنة و...    1.0
# 69576 8978               ماهو العلاج الفعال للبواسير المجروحة؟و    1.0
#       56635   ما هو علاج الشرخ الشرجى بدون عمليات جراحيه وبد...    0.0
#       66564   ماهي الطرق او تمارين تساعد في الشفاء من البواس...    1.0
# ...                                                         ...    ...
# 66718 364491  اشعر بانقباض يضايقني على مستوى المعدة وبدقات ق...    1.0
#       372893  هل أعصاب المعدة سبب يساعد ع الوسوسة و توتر نفس...    1.0
#       720920  لدي الم وسط البطن مع تحجر المنطقة فوق السرة كا...    0.0
# 66715 42543   أعاني من حساسية في بشرة وجهي في فصل الربيع حيث...    1.0
#       54742   عمري 24 سنه ودائما يطلع في وجهي حبوب تحت الجلد...    1.0
#       56706   اعاني من حب الشباب بعد الولاده والرضاعه مع الع...    1.0
#       58177   اعاني هذه الفترة من حبوب تحت الجلد لونها مائل ...    1.0
#       68780   السلام عليكم اما بعد انا فتاة ابلغ من العمر 33...    1.0
#       70595   اعانى منذ اكثر من شهر من حبوب به ماده بيضاء تظ...    1.0
#       218846  يادكتور اعاني من الحبوب او البثور التي تضهر في...    1.0
#       593669  السلام عليكم اعاني من ظهور حبوب دهنية بكثرة عل...    1.0
#       829322  أعاني باستمرار من ظهور الحبوب على وجهي رغم أن ...    1.0
# 66713 24877   ماهي المعلومات عن انخفاض دقات القلب وايضاماهي ...    1.0
#       31036   هل معدل دقات القلب 85 طبيعية لأن دقات قلبي هكذ...    1.0
#       38495   لماذا دقات قلب الانسان البالغ اقل من دقات قلب ...    1.0
#       58127   ماهي الاعضاء التي تبقى حية في الانسان بعد موته...    0.0
#       93012   معدل ضربات القلب في الدقيقة بين 50-55 هل هذا ا...    1.0
#       182904  هل توجد علاقة بين نقصان وزيادة عدد ضربات القلب...    0.0
#       309036                  ما هي عدد ضربات القلب فى الدقيقة؟    1.0
#       352144  هل نبضات الانسان السمين تكون اعلى من الانسان ا...    1.0
#       648111       السلام عليكم. ما هو معدل دقات القلب الطبيعية    1.0
# 66711 46944   ما هي الادويه التي تزيد الوزن عمري إقواستخدمة ...    0.0
#       78260   أنا فتاه عمري 28 سنه عملت فحص دم ونيتجة قوة ال...    0.0
#       115106  هل البروتينات عامة(حيوانى او نباتى) ترفع ضغط ا...    0.0
#       195574   هل يوجد اطعمه طبيعيه تحتوي او غنيه بالجلوتامين ؟    0.0
#       280600  عمري 25 الوزن 74 الطول 172 نسبة الدهون 22% اقو...    0.0
#       355209  ما هي اهم.الاغذيه التي تحتوي على البروتين يجب ...    0.0
#       380008  الواي بروتين المخصص للرياضيي كمال الاجسام هل ي...    0.0
#       499827  عندي ابني عمره سنتين و نصف و يعاني من حساسية ا...    0.0
#       882992        وزني 60 طولي 177 هل أنا نحيف ؟ مع إني رياضي    0.0
#
#                                                           Qtext     score  \
# QID   QAID
# 69579 43523   عدم انتظام ضربات القلب بعد الاصابة بالتهاب الل...  0.557242
#       51753   عدم انتظام ضربات القلب بعد الاصابة بالتهاب الل...  0.557242
#       61846   عدم انتظام ضربات القلب بعد الاصابة بالتهاب الل...  0.557242
#       63972   عدم انتظام ضربات القلب بعد الاصابة بالتهاب الل...  0.557242
#       117912  عدم انتظام ضربات القلب بعد الاصابة بالتهاب الل...  0.557242
#       229172  عدم انتظام ضربات القلب بعد الاصابة بالتهاب الل...  0.645821
#       289894  عدم انتظام ضربات القلب بعد الاصابة بالتهاب الل...  0.557242
#       684584  عدم انتظام ضربات القلب بعد الاصابة بالتهاب الل...  0.443390
#       880238  عدم انتظام ضربات القلب بعد الاصابة بالتهاب الل...  0.557242
# 69578 47192   متزوجة منذ شهرين في الشهر الاول جاتني دورة يوم...  0.625914
#       52302   متزوجة منذ شهرين في الشهر الاول جاتني دورة يوم...  0.638504
#       86270   متزوجة منذ شهرين في الشهر الاول جاتني دورة يوم...  0.826407
#       304444  متزوجة منذ شهرين في الشهر الاول جاتني دورة يوم...  0.809385
#       432499  متزوجة منذ شهرين في الشهر الاول جاتني دورة يوم...  0.580418
#       561870  متزوجة منذ شهرين في الشهر الاول جاتني دورة يوم...  0.497145
#       696681  متزوجة منذ شهرين في الشهر الاول جاتني دورة يوم...  0.640202
#       756956  متزوجة منذ شهرين في الشهر الاول جاتني دورة يوم...  0.753696
#       875015  متزوجة منذ شهرين في الشهر الاول جاتني دورة يوم...  0.625914
# 69577 22960   اعاني من دوخة خفيفة وتعب وضيق تنفس .. وفي الاو...  0.614315
#       28732   اعاني من دوخة خفيفة وتعب وضيق تنفس .. وفي الاو...  0.557242
#       37830   اعاني من دوخة خفيفة وتعب وضيق تنفس .. وفي الاو...  0.560020
#       53616   اعاني من دوخة خفيفة وتعب وضيق تنفس .. وفي الاو...  0.560020
#       65280   اعاني من دوخة خفيفة وتعب وضيق تنفس .. وفي الاو...  0.503946
#       108734  اعاني من دوخة خفيفة وتعب وضيق تنفس .. وفي الاو...  0.560020
#       131938  اعاني من دوخة خفيفة وتعب وضيق تنفس .. وفي الاو...  0.648374
#       293946  اعاني من دوخة خفيفة وتعب وضيق تنفس .. وفي الاو...  0.557242
#       836838  اعاني من دوخة خفيفة وتعب وضيق تنفس .. وفي الاو...  0.627623
# 69576 8978                       ما هو علاج البواسير بالاعشاب ؟  0.557242
#       56635                      ما هو علاج البواسير بالاعشاب ؟  0.592642
#       66564                      ما هو علاج البواسير بالاعشاب ؟  0.723740
# ...                                                         ...       ...
# 66718 364491                      المعده سريعه جدا نتيجه توتر ؟  0.557242
#       372893                      المعده سريعه جدا نتيجه توتر ؟  0.557242
#       720920                      المعده سريعه جدا نتيجه توتر ؟  0.557242
# 66715 42543   اعاني من ظهور الحبوب في وجهي باستمرار على الجب...  0.635377
#       54742   اعاني من ظهور الحبوب في وجهي باستمرار على الجب...  0.538533
#       56706   اعاني من ظهور الحبوب في وجهي باستمرار على الجب...  0.557242
#       58177   اعاني من ظهور الحبوب في وجهي باستمرار على الجب...  0.716789
#       68780   اعاني من ظهور الحبوب في وجهي باستمرار على الجب...  0.468466
#       70595   اعاني من ظهور الحبوب في وجهي باستمرار على الجب...  0.503946
#       218846  اعاني من ظهور الحبوب في وجهي باستمرار على الجب...  0.624179
#       593669  اعاني من ظهور الحبوب في وجهي باستمرار على الجب...  0.551125
#       829322  اعاني من ظهور الحبوب في وجهي باستمرار على الجب...  0.701300
# 66713 24877           ما عدد ضربات القلب الطبيعية عند الإنسان ؟  0.557242
#       31036           ما عدد ضربات القلب الطبيعية عند الإنسان ؟  0.557242
#       38495           ما عدد ضربات القلب الطبيعية عند الإنسان ؟  0.557242
#       58127           ما عدد ضربات القلب الطبيعية عند الإنسان ؟  0.557242
#       93012           ما عدد ضربات القلب الطبيعية عند الإنسان ؟  0.443390
#       182904          ما عدد ضربات القلب الطبيعية عند الإنسان ؟  0.500820
#       309036          ما عدد ضربات القلب الطبيعية عند الإنسان ؟  0.670727
#       352144          ما عدد ضربات القلب الطبيعية عند الإنسان ؟  0.485921
#       648111          ما عدد ضربات القلب الطبيعية عند الإنسان ؟  0.557242
# 66711 46944   البقوليات غنية بالبروتينات وهي بروتين نباتي كم...  0.557242
#       78260   البقوليات غنية بالبروتينات وهي بروتين نباتي كم...  0.490917
#       115106  البقوليات غنية بالبروتينات وهي بروتين نباتي كم...  0.550265
#       195574  البقوليات غنية بالبروتينات وهي بروتين نباتي كم...  0.497191
#       280600  البقوليات غنية بالبروتينات وهي بروتين نباتي كم...  0.557242
#       355209  البقوليات غنية بالبروتينات وهي بروتين نباتي كم...  0.597307
#       380008  البقوليات غنية بالبروتينات وهي بروتين نباتي كم...  0.540409
#       499827  البقوليات غنية بالبروتينات وهي بروتين نباتي كم...  0.589509
#       882992  البقوليات غنية بالبروتينات وهي بروتين نباتي كم...  0.497191
#
#              relevance  rank
# QID   QAID
# 69579 43523       true     0
#       51753       true     0
#       61846       true     0
#       63972       true     0
#       117912      true     0
#       229172      true     0
#       289894      true     0
#       684584     false     0
#       880238      true     0
# 69578 47192       true     0
#       52302       true     0
#       86270       true     0
#       304444      true     0
#       432499      true     0
#       561870     false     0
#       696681      true     0
#       756956      true     0
#       875015      true     0
# 69577 22960       true     0
#       28732       true     0
#       37830       true     0
#       53616       true     0
#       65280       true     0
#       108734      true     0
#       131938      true     0
#       293946      true     0
#       836838      true     0
# 69576 8978        true     0
#       56635       true     0
#       66564       true     0
# ...                ...   ...
# 66718 364491      true     0
#       372893      true     0
#       720920      true     0
# 66715 42543       true     0
#       54742       true     0
#       56706       true     0
#       58177       true     0
#       68780      false     0
#       70595       true     0
#       218846      true     0
#       593669      true     0
#       829322      true     0
# 66713 24877       true     0
#       31036       true     0
#       38495       true     0
#       58127       true     0
#       93012      false     0
#       182904      true     0
#       309036      true     0
#       352144     false     0
#       648111      true     0
# 66711 46944       true     0
#       78260      false     0
#       115106      true     0
#       195574     false     0
#       280600      true     0
#       355209      true     0
#       380008      true     0
#       499827      true     0
#       882992     false     0
#
# [12581 rows x 9 columns]

# %%
MAP, Accuracy, P, R, F1  = evaluate('../EVAL/SemEval2017-Task3-CQA-MD-test.xml.subtaskD.relevancy', '../EVAL/SemEval2017-Task3-CQA-MD-test-lsa-mlp.xml.pred')

# %%
MAP
# Out:
# 0.5369180221493354
